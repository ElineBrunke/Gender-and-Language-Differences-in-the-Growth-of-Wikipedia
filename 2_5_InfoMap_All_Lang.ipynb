# %%
import pandas as pd
import get_dataremodelled as gdr
from infomap import Infomap
import graphcreating as gc

# %% [markdown]
# ### Data
# Loading all data and merging with gender information

# %%
#download the data 
df_en=pd.read_csv('Data/revisions_en.csv')
df_de=pd.read_csv('Data/revisions_de.csv')
df_fr=pd.read_csv('Data/revisions_fr.csv')
df_es=pd.read_csv('Data/revisions_es.csv')
gender=pd.read_csv('gendered_titles_final.csv')
text_df=pd.read_csv('gendered_titles_final.csv')
names=text_df['Name'].tolist()

# %%
gender=gender.drop_duplicates(subset='Name')

# %%
df_en=gdr.prep_data(df_en,gender)
df_de=gdr.prep_data(df_de,gender)
df_fr=gdr.prep_data(df_fr,gender)
df_es=gdr.prep_data(df_es,gender)

# %%
df_en=gdr.prep_links(df_en, gender)
df_de=gdr.prep_links(df_de, gender)
df_fr=gdr.prep_links(df_fr, gender)
df_es=gdr.prep_links(df_es, gender)

# %% [markdown]
# ### Finding communities for the English network.
#
# Creating the graph, doing the node mapping, running infomap and creating the summary table for each year.

# %%
all_communities_data = []

for year in range(2002, 2025):
    df_en_year = df_en[df_en['Year'] == year]

    G_en = gc.create_directed_graph(df_en_year, gender)
    
    # Node mapping for Infomap processing
    node_mapping = {node: i for i, node in enumerate(G_en.nodes())}
    reverse_mapping = {i: node for node, i in node_mapping.items()}
    infomap = Infomap("--directed")
    
    # Adding edges to Infomap with weights
    for u, v, data in G_en.edges(data=True):
        weight = data.get('weight', 1)
        infomap.add_link(node_mapping[u], node_mapping[v], weight)
    
    infomap.run()
    
    # Create summary table
    community_summary = {}
    for node in infomap.tree:
        if node.is_leaf:
            original_node = reverse_mapping[node.node_id]
            community_id = node.module_id

            if community_id not in community_summary:
                community_summary[community_id] = {"members": [], "female_count": 0}

            community_summary[community_id]["members"].append(original_node)

            if original_node in G_en.nodes and "gender" in G_en.nodes[original_node]:
                gender_value = G_en.nodes[original_node]["gender"]

                if isinstance(gender_value, pd.Series):
                    if not gender_value.empty:
                        gender_value = gender_value.iloc[0]
                elif isinstance(gender_value, list):
                    gender_value = gender_value[0]

                if gender_value == "f":
                    community_summary[community_id]["female_count"] += 1

    community_data = []
    for community_id, data in community_summary.items():
        size = len(data["members"])
        female_count = data["female_count"]
        female_percentage = (female_count / size) * 100 if size > 0 else 0
        members_string = ", ".join(data["members"])

        community_data.append({
            "Year": year,
            "Community ID": community_id,
            "Size": size,
            "Number of Women": female_count,
            "Percentage of Women": female_percentage,
            "Members": members_string
        })

    all_communities_data.extend(community_data)

all_communities_df = pd.DataFrame(all_communities_data)

all_communities_df.to_csv("all_communities_infomap.csv", sep=";", index=False)

# %% [markdown]
# ### Finding communities for the German, French and Spanish networks

# %%
all_communities_data = []

for year in range(2002, 2025):
    df_de_year = df_de[df_de['Year'] == year]

    G_de = gc.create_directed_graph(df_de_year, gender)

    node_mapping = {node: i for i, node in enumerate(G_de.nodes())}
    reverse_mapping = {i: node for node, i in node_mapping.items()}
    infomap = Infomap("--directed")

    for u, v, data in G_de.edges(data=True):
        weight = data.get('weight', 1)
        infomap.add_link(node_mapping[u], node_mapping[v], weight)
    
    infomap.run()

    community_summary = {}
    for node in infomap.tree:
        if node.is_leaf:
            original_node = reverse_mapping[node.node_id]
            community_id = node.module_id

            if community_id not in community_summary:
                community_summary[community_id] = {"members": [], "female_count": 0}

            community_summary[community_id]["members"].append(original_node)

            if original_node in G_de.nodes and "gender" in G_de.nodes[original_node]:
                gender_value = G_de.nodes[original_node]["gender"]

                if isinstance(gender_value, pd.Series):
                    if not gender_value.empty:
                        gender_value = gender_value.iloc[0]
                elif isinstance(gender_value, list):
                    gender_value = gender_value[0]

                if gender_value == "f":
                    community_summary[community_id]["female_count"] += 1

    community_data = []
    for community_id, data in community_summary.items():
        size = len(data["members"])
        female_count = data["female_count"]
        female_percentage = (female_count / size) * 100 if size > 0 else 0
        members_string = ", ".join(data["members"])

        community_data.append({
            "Year": year,
            "Community ID": community_id,
            "Size": size,
            "Number of Women": female_count,
            "Percentage of Women": female_percentage,
            "Members": members_string
        })

    all_communities_data.extend(community_data)

all_communities_df = pd.DataFrame(all_communities_data)

all_communities_df.to_csv("all_communities_infomap_de.csv", sep=";", index=False)
# Out:
# =======================================================
#   Infomap v2.8.0 starts at 2024-11-29 20:11:14
#   -> Input network:
#   -> No file output!
#   -> Configuration: directed
# =======================================================
#   -> Ordinary network input, using the Map Equation for first order network flows
# Calculating global network flow using flow model 'directed'...
#   -> Using unrecorded teleportation to links.
#   -> PageRank calculation done in 200 iterations.
#
#   => Sum node flow: 1, sum link flow: 1
# Build internal network with 66 nodes and 48 links...
#   -> One-level codelength: 4.8167023
#
# ================================================
# Trial 1/1 starting at 2024-11-29 20:11:14
# ================================================
# Two-level compression: 74% 1.8e-13%
# Partitioned to codelength 0.0728198037 + 1.18469911 = 1.257518911 in 24 modules.
# Super-level compression: 3.71314611% to codelength 1.210825397 in 21 top modules.
#
# Recursive sub-structure compression: 19.3857521% 1.62884007% 0% . Found 4 levels with codelength 1.191102988
#
# => Trial 1/1 finished in 0.000781833s with codelength 1.19110299
#
#
# ================================================
# Summary after 1 trial
# ================================================
# Best end modular solution in 4 levels:
# Per level number of modules:         [         21,           8,           4,           0] (sum: 33)
# Per level number of leaf nodes:      [          0,          50,          10,           6] (sum: 66)
# Per level average child degree:      [         21,      2.7619,        1.75,         1.5] (average: 6.41101)
# Per level codelength for modules:    [0.000000000, 0.171638167, 0.000000000, 0.000000000] (sum: 0.171638167)
# Per level codelength for leaf nodes: [0.000000000, 0.493632023, 0.473580219, 0.052252578] (sum: 1.019464821)
# Per level codelength total:          [0.000000000, 0.665270190, 0.473580219, 0.052252578] (sum: 1.191102988)
#
# ===================================================
#   Infomap ends at 2024-11-29 20:11:14
#   (Elapsed time: 0.00107275s)
# ===================================================
# =======================================================
#   Infomap v2.8.0 starts at 2024-11-29 20:11:16
#   -> Input network:
#   -> No file output!
#   -> Configuration: directed
# =======================================================
#   -> Ordinary network input, using the Map Equation for first order network flows
# Calculating global network flow using flow model 'directed'...
#   -> Using unrecorded teleportation to links.
#   -> PageRank calculation done in 200 iterations.
#
#   => Sum node flow: 1, sum link flow: 1
# Build internal network with 258 nodes and 212 links...
#   -> One-level codelength: 6.63646751
#
# ================================================
# Trial 1/1 starting at 2024-11-29 20:11:16
# ================================================
# Two-level compression: 75% 6.5e-13% 0.077498858%
# Partitioned to codelength 0.113244202 + 1.52649457 = 1.639738775 in 87 (86 non-trivial) modules.
# Super-level compression: 3.40565738% to codelength 1.58389489 in 78 top modules.
#
# Recursive sub-structure compression: 15.2741301% 6.88349332% 0.442063605% 0% . Found 5 levels with codelength 1.496077332
#
# => Trial 1/1 finished in 0.002409625s with codelength 1.49607733
#
#
# ================================================
# Summary after 1 trial
# ================================================
# Best end modular solution in 5 levels:
# Per level number of modules:         [         78,          30,          12,           4,           0] (sum: 124)
# Per level number of leaf nodes:      [          0,         161,          60,          29,           8] (sum: 258)
# Per level average child degree:      [         78,     2.44872,         2.4,        2.75,           2] (average: 17.8829)
# Per level codelength for modules:    [0.000000000, 0.043378592, 0.041973648, 0.008672043, 0.000000000] (sum: 0.094024284)
# Per level codelength for leaf nodes: [0.000000000, 0.802708235, 0.256054682, 0.333264132, 0.010025998] (sum: 1.402053048)
# Per level codelength total:          [0.000000000, 0.846086828, 0.298028331, 0.341936175, 0.010025998] (sum: 1.496077332)
#
# ===================================================
#   Infomap ends at 2024-11-29 20:11:16
#   (Elapsed time: 0.002784041s)
# ===================================================
# =======================================================
#   Infomap v2.8.0 starts at 2024-11-29 20:11:19
#   -> Input network:
#   -> No file output!
#   -> Configuration: directed
# =======================================================
#   -> Ordinary network input, using the Map Equation for first order network flows
# Calculating global network flow using flow model 'directed'...
#   -> Using unrecorded teleportation to links.
#   -> PageRank calculation done in 200 iterations.
#
#   => Sum node flow: 1, sum link flow: 1
# Build internal network with 672 nodes and 671 links...
#   -> One-level codelength: 7.93666722
#
# ================================================
# Trial 1/1 starting at 2024-11-29 20:11:19
# ================================================
# Two-level compression: 71% 0.48% 0.0320988387%
# Partitioned to codelength 0.365267912 + 1.9596528 = 2.324920713 in 195 modules.
# Super-level compression: 7.04090025% 0.145919739% 0.0101293847% to codelength 2.157853111 in 149 top modules.
#
# Recursive sub-structure compression: 15.2172052% 16.0536851% 11.2813972% 4.27424405% 2.60475661% 1.57676844% 0.147035306% 0.0611776136% 0% . Found 10 levels with codelength 2.046153409
#
# => Trial 1/1 finished in 0.010287167s with codelength 2.04615341
#
#
# ================================================
# Summary after 1 trial
# ================================================
# Best end modular solution in 10 levels:
# Per level number of modules:         [        149,          40,          32,          33,          13,          16,          12,           8,           2,           0] (sum: 305)
# Per level number of leaf nodes:      [          0,         315,          73,          79,         100,          16,          47,          26,          11,           5] (sum: 672)
# Per level average child degree:      [        149,     2.38255,       2.625,         3.5,     3.42424,     2.46154,      3.6875,     2.83333,       1.625,         2.5] (average: 25.1051)
# Per level codelength for modules:    [0.015876649, 0.040075129, 0.084395003, 0.126711825, 0.009840216, 0.006108277, 0.006354045, 0.008568334, 0.000000000, 0.000000000] (sum: 0.297929477)
# Per level codelength for leaf nodes: [0.000000000, 0.343792657, 0.162748688, 0.532011591, 0.467788456, 0.044946352, 0.145610005, 0.041795309, 0.006694619, 0.002836255] (sum: 1.748223932)
# Per level codelength total:          [0.015876649, 0.383867786, 0.247143690, 0.658723416, 0.477628672, 0.051054629, 0.151964051, 0.050363643, 0.006694619, 0.002836255] (sum: 2.046153409)
#
# ===================================================
#   Infomap ends at 2024-11-29 20:11:19
#   (Elapsed time: 0.011152166s)
# ===================================================
# =======================================================
#   Infomap v2.8.0 starts at 2024-11-29 20:11:26
#   -> Input network:
#   -> No file output!
#   -> Configuration: directed
# =======================================================
#   -> Ordinary network input, using the Map Equation for first order network flows
# Calculating global network flow using flow model 'directed'...
#   -> Using unrecorded teleportation to links.
#   -> PageRank calculation done in 200 iterations.
#
#   => Sum node flow: 1, sum link flow: 1
# Build internal network with 1315 nodes and 1620 links...
#   -> One-level codelength: 8.76947051
#
# ================================================
# Trial 1/1 starting at 2024-11-29 20:11:26
# ================================================
# Two-level compression: 63% 0.47% 0.011151805%
# Partitioned to codelength 0.665955453 + 2.58706808 = 3.253023533 in 329 modules.
# Super-level compression: 4.68023639% to codelength 3.100774342 in 232 top modules.
#
# Recursive sub-structure compression: 26.5613371% 5.48378385% 0.678901427% 0.0725202454% 0.00565420152% 0% . Found 7 levels with codelength 2.952793603
#
# => Trial 1/1 finished in 0.017227375s with codelength 2.9527936
#
#
# ================================================
# Summary after 1 trial
# ================================================
# Best end modular solution in 7 levels:
# Per level number of modules:         [        232,         143,         107,          48,          11,           2,           0] (sum: 543)
# Per level number of leaf nodes:      [          0,         483,         403,         286,         118,          22,           3] (sum: 1315)
# Per level average child degree:      [        232,     2.69828,     3.56643,      3.1215,      2.6875,     2.18182,         1.5] (average: 31.6352)
# Per level codelength for modules:    [0.089892307, 0.520052011, 0.133915288, 0.020287468, 0.002414859, 0.000000000, 0.000000000] (sum: 0.766561933)
# Per level codelength for leaf nodes: [0.000000000, 0.234561433, 1.206249086, 0.615998398, 0.120700737, 0.008279654, 0.000442361] (sum: 2.186231670)
# Per level codelength total:          [0.089892307, 0.754613445, 1.340164375, 0.636285866, 0.123115596, 0.008279654, 0.000442361] (sum: 2.952793603)
#
# ===================================================
#   Infomap ends at 2024-11-29 20:11:26
#   (Elapsed time: 0.018995541s)
# ===================================================
# =======================================================
#   Infomap v2.8.0 starts at 2024-11-29 20:11:35
#   -> Input network:
#   -> No file output!
#   -> Configuration: directed
# =======================================================
#   -> Ordinary network input, using the Map Equation for first order network flows
# Calculating global network flow using flow model 'directed'...
#   -> Using unrecorded teleportation to links.
#   -> PageRank calculation done in 200 iterations.
#
#   => Sum node flow: 1, sum link flow: 1
# Build internal network with 1883 nodes and 2609 links...
#   -> One-level codelength: 9.16992956
#
# ================================================
# Trial 1/1 starting at 2024-11-29 20:11:35
# ================================================
# Two-level compression: 57% 0.35%
# Partitioned to codelength 0.983034822 + 2.9667459 = 3.949780722 in 409 (407 non-trivial) modules.
# Super-level compression: 3.82563896% to codelength 3.798676372 in 255 top modules.
#
# Recursive sub-structure compression: 29.545637% 7.3953588% 0.697206668% 0.0924956535% 0.036102608% 0.00535528272% 0.00414271799% 0.00251175344% 0% . Found 10 levels with codelength 3.67804829
#
# => Trial 1/1 finished in 0.024717542s with codelength 3.67804829
#
#
# ================================================
# Summary after 1 trial
# ================================================
# Best end modular solution in 10 levels:
# Per level number of modules:         [        255,         196,         193,          70,          25,           6,           2,           2,           2,           0] (sum: 751)
# Per level number of leaf nodes:      [          0,         510,         656,         510,         144,          46,          12,           1,           1,           3] (sum: 1883)
# Per level average child degree:      [        255,     2.76863,     4.33163,     3.00518,     2.41429,        2.08,     2.33333,         1.5,         1.5,         1.5] (average: 27.7003)
# Per level codelength for modules:    [0.088677216, 0.771449484, 0.172440888, 0.016934457, 0.003874325, 0.000686528, 0.000000000, 0.000244767, 0.000000000, 0.000000000] (sum: 1.054307665)
# Per level codelength for leaf nodes: [0.000000000, 0.126516158, 1.748820980, 0.642856468, 0.087948128, 0.014985321, 0.002368802, 0.000000000, 0.000000000, 0.000244767] (sum: 2.623740624)
# Per level codelength total:          [0.088677216, 0.897965643, 1.921261868, 0.659790925, 0.091822453, 0.015671849, 0.002368802, 0.000244767, 0.000000000, 0.000244767] (sum: 3.678048290)
#
# ===================================================
#   Infomap ends at 2024-11-29 20:11:35
#   (Elapsed time: 0.027292208s)
# ===================================================
# =======================================================
#   Infomap v2.8.0 starts at 2024-11-29 20:11:47
#   -> Input network:
#   -> No file output!
#   -> Configuration: directed
# =======================================================
#   -> Ordinary network input, using the Map Equation for first order network flows
# Calculating global network flow using flow model 'directed'...
#   -> Using unrecorded teleportation to links.
#   -> PageRank calculation done in 200 iterations.
#
#   => Sum node flow: 1, sum link flow: 1
# Build internal network with 2476 nodes and 3879 links...
#   -> One-level codelength: 9.52412475
#
# ================================================
# Trial 1/1 starting at 2024-11-29 20:11:47
# ================================================
# Two-level compression: 52% 0.44% 0.00986940528%
# Partitioned to codelength 1.17970606 + 3.35299521 = 4.532701275 in 492 (491 non-trivial) modules.
# Super-level compression: 3.59788771% to codelength 4.369619773 in 271 top modules.
#
# Recursive sub-structure compression: 27.6750636% 5.34824597% 0.14407383% 0.0247375195% 0.00430728616% 0.00226822727% 0.00137521329% 0% . Found 9 levels with codelength 4.277644378
#
# => Trial 1/1 finished in 0.034001958s with codelength 4.27764438
#
#
# ================================================
# Summary after 1 trial
# ================================================
# Best end modular solution in 9 levels:
# Per level number of modules:         [        271,         317,         213,          52,          10,           4,           2,           2,           0] (sum: 871)
# Per level number of leaf nodes:      [          0,         531,        1224,         593,         104,          16,           4,           1,           3] (sum: 2476)
# Per level average child degree:      [        271,     3.12915,     4.53312,     3.02817,     2.19231,           2,         1.5,         1.5,         1.5] (average: 25.3569)
# Per level codelength for modules:    [0.174712849, 1.067672842, 0.151208987, 0.008208746, 0.000807696, 0.000155858, 0.000155858, 0.000000000, 0.000000000] (sum: 1.402922836)
# Per level codelength for leaf nodes: [0.000000000, 0.080421704, 2.196623119, 0.566233370, 0.029986760, 0.001300730, 0.000000000, 0.000000000, 0.000155858] (sum: 2.874721541)
# Per level codelength total:          [0.174712849, 1.148094546, 2.347832106, 0.574442116, 0.030794457, 0.001456587, 0.000155858, 0.000000000, 0.000155858] (sum: 4.277644378)
#
# ===================================================
#   Infomap ends at 2024-11-29 20:11:47
#   (Elapsed time: 0.037674958s)
# ===================================================
# =======================================================
#   Infomap v2.8.0 starts at 2024-11-29 20:12:07
#   -> Input network:
#   -> No file output!
#   -> Configuration: directed
# =======================================================
#   -> Ordinary network input, using the Map Equation for first order network flows
# Calculating global network flow using flow model 'directed'...
#   -> Using unrecorded teleportation to links.
#   -> PageRank calculation done in 200 iterations.
#
#   => Sum node flow: 1, sum link flow: 1
# Build internal network with 3181 nodes and 5863 links...
#   -> One-level codelength: 9.86208337
#
# ================================================
# Trial 1/1 starting at 2024-11-29 20:12:07
# ================================================
# Two-level compression: 46% 0.46% 0.0228263152% 0.00655679216%
# Partitioned to codelength 1.61556583 + 3.65646125 = 5.272027073 in 556 (555 non-trivial) modules.
# Super-level compression: 2.60259998% to codelength 5.134817297 in 270 top modules.
#
# Recursive sub-structure compression: 26.0830092% 5.29197021% 0.0951571103% 0.00534983061% 0% . Found 6 levels with codelength 5.050684845
#
# => Trial 1/1 finished in 0.053334333s with codelength 5.05068484
#
#
# ================================================
# Summary after 1 trial
# ================================================
# Best end modular solution in 6 levels:
# Per level number of modules:         [        270,         390,         265,          63,          12,           0] (sum: 1000)
# Per level number of leaf nodes:      [          0,         542,        1684,         806,         131,          18] (sum: 3181)
# Per level average child degree:      [        270,     3.45185,     4.99744,     3.27925,     2.26984,         1.5] (average: 21.3007)
# Per level codelength for modules:    [0.153673391, 1.484472327, 0.198266111, 0.007182498, 0.000652644, 0.000000000] (sum: 1.844246972)
# Per level codelength for leaf nodes: [0.000000000, 0.058965894, 2.521682850, 0.592282114, 0.033408467, 0.000098549] (sum: 3.206437873)
# Per level codelength total:          [0.153673391, 1.543438221, 2.719948961, 0.599464612, 0.034061111, 0.000098549] (sum: 5.050684845)
#
# ===================================================
#   Infomap ends at 2024-11-29 20:12:07
#   (Elapsed time: 0.058158625s)
# ===================================================
# =======================================================
#   Infomap v2.8.0 starts at 2024-11-29 20:12:37
#   -> Input network:
#   -> No file output!
#   -> Configuration: directed
# =======================================================
#   -> Ordinary network input, using the Map Equation for first order network flows
# Calculating global network flow using flow model 'directed'...
#   -> Using unrecorded teleportation to links.
#   -> PageRank calculation done in 200 iterations.
#
#   => Sum node flow: 1, sum link flow: 1
# Build internal network with 3818 nodes and 7561 links...
#   -> One-level codelength: 10.0428048
#
# ================================================
# Trial 1/1 starting at 2024-11-29 20:12:37
# ================================================
# Two-level compression: 43% 0.46% 0.0508570414% 0.0142283115%
# Partitioned to codelength 1.79382179 + 3.86970781 = 5.663529596 in 655 (653 non-trivial) modules.
# Super-level compression: 2.53935014% to codelength 5.519712749 in 293 top modules.
#
# Recursive sub-structure compression: 25.7683126% 0.4993794% 0.0456831844% 0.00225110394% 0% . Found 6 levels with codelength 5.42765172
#
# => Trial 1/1 finished in 0.066153125s with codelength 5.42765172
#
#
# ================================================
# Summary after 1 trial
# ================================================
# Best end modular solution in 6 levels:
# Per level number of modules:         [        293,         528,         287,          50,           4,           0] (sum: 1162)
# Per level number of leaf nodes:      [          0,         599,        2466,         645,         101,           7] (sum: 3818)
# Per level average child degree:      [        293,     3.84642,     5.21402,      2.4216,         2.1,        1.75] (average: 21.3763)
# Per level codelength for modules:    [0.301095886, 1.719909759, 0.047918015, 0.003698630, 0.000071138, 0.000000000] (sum: 2.072693427)
# Per level codelength for leaf nodes: [0.000000000, 0.048186439, 3.102882250, 0.187318398, 0.016307314, 0.000263892] (sum: 3.354958293)
# Per level codelength total:          [0.301095886, 1.768096198, 3.150800265, 0.191017028, 0.016378451, 0.000263892] (sum: 5.427651720)
#
# ===================================================
#   Infomap ends at 2024-11-29 20:12:37
#   (Elapsed time: 0.072111667s)
# ===================================================
# =======================================================
#   Infomap v2.8.0 starts at 2024-11-29 20:13:14
#   -> Input network:
#   -> No file output!
#   -> Configuration: directed
# =======================================================
#   -> Ordinary network input, using the Map Equation for first order network flows
# Calculating global network flow using flow model 'directed'...
#   -> Using unrecorded teleportation to links.
#   -> PageRank calculation done in 200 iterations.
#
#   => Sum node flow: 1, sum link flow: 1
# Build internal network with 4332 nodes and 9219 links...
#   -> One-level codelength: 10.2676864
#
# ================================================
# Trial 1/1 starting at 2024-11-29 20:13:14
# ================================================
# Two-level compression: 41% 0.45% 0.00699629677% 0.00812774274% 0.0352568553%
# Partitioned to codelength 1.96842356 + 4.05113577 = 6.019559336 in 698 (697 non-trivial) modules.
# Super-level compression: 2.2012959% to codelength 5.887051023 in 302 top modules.
#
# Recursive sub-structure compression: 25.4415098% 0.270038139% 0.0301485692% 0.000961380098% 0% . Found 6 levels with codelength 5.836181506
#
# => Trial 1/1 finished in 0.083959458s with codelength 5.83618151
#
#
# ================================================
# Summary after 1 trial
# ================================================
# Best end modular solution in 6 levels:
# Per level number of modules:         [        302,         614,         223,          37,           4,           0] (sum: 1180)
# Per level number of leaf nodes:      [          0,         610,        3142,         498,          75,           7] (sum: 4332)
# Per level average child degree:      [        302,     4.05298,     5.48046,      2.3991,     2.13514,        1.75] (average: 21.0579)
# Per level codelength for modules:    [0.280713630, 1.835218456, 0.039270587, 0.002608094, 0.000000000, 0.000000000] (sum: 2.157810767)
# Per level codelength for leaf nodes: [0.000000000, 0.037180952, 3.483386140, 0.137036270, 0.020655161, 0.000112217] (sum: 3.678370739)
# Per level codelength total:          [0.280713630, 1.872399408, 3.522656727, 0.139644364, 0.020655161, 0.000112217] (sum: 5.836181506)
#
# ===================================================
#   Infomap ends at 2024-11-29 20:13:14
#   (Elapsed time: 0.094562042s)
# ===================================================
# =======================================================
#   Infomap v2.8.0 starts at 2024-11-29 20:14:00
#   -> Input network:
#   -> No file output!
#   -> Configuration: directed
# =======================================================
#   -> Ordinary network input, using the Map Equation for first order network flows
# Calculating global network flow using flow model 'directed'...
#   -> Using unrecorded teleportation to links.
#   -> PageRank calculation done in 200 iterations.
#
#   => Sum node flow: 1, sum link flow: 1
# Build internal network with 4727 nodes and 10564 links...
#   -> One-level codelength: 10.4584888
#
# ================================================
# Trial 1/1 starting at 2024-11-29 20:14:00
# ================================================
# Two-level compression: 40% 0.46% 0.0269520979% 0.0148281548%
# Partitioned to codelength 2.24748174 + 4.04120166 = 6.288683399 in 722 (718 non-trivial) modules.
# Super-level compression: 2.31002875% to codelength 6.143413005 in 284 top modules.
#
# Recursive sub-structure compression: 26.8166099% 0.279135084% 0.0292306907% 0% . Found 5 levels with codelength 6.090636713
#
# => Trial 1/1 finished in 0.082596834s with codelength 6.09063671
#
#
# ================================================
# Summary after 1 trial
# ================================================
# Best end modular solution in 5 levels:
# Per level number of modules:         [        284,         618,         242,          37,           0] (sum: 1181)
# Per level number of leaf nodes:      [          0,         605,        3461,         582,          79] (sum: 4727)
# Per level average child degree:      [        284,     4.30634,     5.99191,     2.55785,     2.13514] (average: 18.5956)
# Per level codelength for modules:    [0.243539912, 2.013247505, 0.033463237, 0.001465845, 0.000000000] (sum: 2.291716499)
# Per level codelength for leaf nodes: [0.000000000, 0.039803431, 3.627811919, 0.123488158, 0.007816705] (sum: 3.798920213)
# Per level codelength total:          [0.243539912, 2.053050936, 3.661275157, 0.124954003, 0.007816705] (sum: 6.090636713)
#
# ===================================================
#   Infomap ends at 2024-11-29 20:14:00
#   (Elapsed time: 0.091006334s)
# ===================================================
# =======================================================
#   Infomap v2.8.0 starts at 2024-11-29 20:14:57
#   -> Input network:
#   -> No file output!
#   -> Configuration: directed
# =======================================================
#   -> Ordinary network input, using the Map Equation for first order network flows
# Calculating global network flow using flow model 'directed'...
#   -> Using unrecorded teleportation to links.
#   -> PageRank calculation done in 200 iterations.
#
#   => Sum node flow: 1, sum link flow: 1
# Build internal network with 5173 nodes and 11918 links...
#   -> One-level codelength: 10.5789251
#
# ================================================
# Trial 1/1 starting at 2024-11-29 20:14:57
# ================================================
# Two-level compression: 39% 0.47% 0.0841167385% 0.0334167785% 0.0029292245%
# Partitioned to codelength 2.25511683 + 4.1776865 = 6.432803328 in 749 (746 non-trivial) modules.
# Super-level compression: 1.88813849% to codelength 6.311343092 in 273 top modules.
#
# Recursive sub-structure compression: 25.3669743% 0.505337742% 0.0161475318% 0.000517317732% 0% . Found 6 levels with codelength 6.255032947
#
# => Trial 1/1 finished in 0.299522375s with codelength 6.25503295
#
#
# ================================================
# Summary after 1 trial
# ================================================
# Best end modular solution in 6 levels:
# Per level number of modules:         [        273,         660,         355,          50,           2,           0] (sum: 1340)
# Per level number of leaf nodes:      [          0,         581,        3598,         879,         112,           3] (sum: 5173)
# Per level average child degree:      [        273,     4.54579,     5.98939,      2.6169,        2.28,         1.5] (average: 16.3583)
# Per level codelength for modules:    [0.282613433, 2.091066967, 0.062037913, 0.001690496, 0.000000000, 0.000000000] (sum: 2.437408808)
# Per level codelength for leaf nodes: [0.000000000, 0.037614624, 3.566925941, 0.204066938, 0.008975568, 0.000041068] (sum: 3.817624139)
# Per level codelength total:          [0.282613433, 2.128681591, 3.628963854, 0.205757434, 0.008975568, 0.000041068] (sum: 6.255032947)
#
# ===================================================
#   Infomap ends at 2024-11-29 20:14:57
#   (Elapsed time: 0.334769542s)
# ===================================================
# =======================================================
#   Infomap v2.8.0 starts at 2024-11-29 20:16:08
#   -> Input network:
#   -> No file output!
#   -> Configuration: directed
# =======================================================
#   -> Ordinary network input, using the Map Equation for first order network flows
# Calculating global network flow using flow model 'directed'...
#   -> Using unrecorded teleportation to links.
#   -> PageRank calculation done in 200 iterations.
#
#   => Sum node flow: 1, sum link flow: 1
# Build internal network with 5782 nodes and 13733 links...
#   -> One-level codelength: 10.7617479
#
# ================================================
# Trial 1/1 starting at 2024-11-29 20:16:08
# ================================================
# Two-level compression: 38% 0.48% 0.0866231125% 0.00704989105%
# Partitioned to codelength 2.34119325 + 4.25716178 = 6.598355031 in 820 (818 non-trivial) modules.
# Super-level compression: 2.03534837% to codelength 6.464055519 in 293 top modules.
#
# Recursive sub-structure compression: 24.7403826% 0.390477124% 0.0118571312% 0.000433266312% 0.000143581514% 0% . Found 7 levels with codelength 6.397054779
#
# => Trial 1/1 finished in 0.111104792s with codelength 6.39705478
#
#
# ================================================
# Summary after 1 trial
# ================================================
# Best end modular solution in 7 levels:
# Per level number of modules:         [        293,         764,         341,          28,           2,           2,           0] (sum: 1430)
# Per level number of leaf nodes:      [          0,         610,        4266,         841,          61,           1,           3] (sum: 5782)
# Per level average child degree:      [        293,     4.68942,      6.0301,     2.54839,        2.25,         1.5,         1.5] (average: 16.977)
# Per level codelength for modules:    [0.317735704, 2.228887676, 0.053803385, 0.000447406, 0.000035522, 0.000000000, 0.000000000] (sum: 2.600909693)
# Per level codelength for leaf nodes: [0.000000000, 0.028297467, 3.602065438, 0.162055727, 0.003679132, 0.000000000, 0.000047321] (sum: 3.796145086)
# Per level codelength total:          [0.317735704, 2.257185143, 3.655868824, 0.162503133, 0.003714654, 0.000000000, 0.000047321] (sum: 6.397054779)
#
# ===================================================
#   Infomap ends at 2024-11-29 20:16:08
#   (Elapsed time: 0.122040334s)
# ===================================================
# =======================================================
#   Infomap v2.8.0 starts at 2024-11-29 20:17:16
#   -> Input network:
#   -> No file output!
#   -> Configuration: directed
# =======================================================
#   -> Ordinary network input, using the Map Equation for first order network flows
# Calculating global network flow using flow model 'directed'...
#   -> Using unrecorded teleportation to links.
#   -> PageRank calculation done in 200 iterations.
#
#   => Sum node flow: 1, sum link flow: 1
# Build internal network with 6104 nodes and 15009 links...
#   -> One-level codelength: 10.8785423
#
# ================================================
# Trial 1/1 starting at 2024-11-29 20:17:16
# ================================================
# Two-level compression: 38% 0.53% 0.0471646287% 0.0307622401%
# Partitioned to codelength 2.39452467 + 4.34263349 = 6.737158152 in 846 (844 non-trivial) modules.
# Super-level compression: 1.81688544% to codelength 6.614751707 in 289 top modules.
#
# Recursive sub-structure compression: 28.6076609% 0.22215735% 0.0425078702% 0.00120786475% 0% . Found 6 levels with codelength 6.55472231
#
# => Trial 1/1 finished in 0.114997875s with codelength 6.55472231
#
#
# ================================================
# Summary after 1 trial
# ================================================
# Best end modular solution in 6 levels:
# Per level number of modules:         [        289,         734,         315,          49,           7,           0] (sum: 1394)
# Per level number of leaf nodes:      [          0,         622,        4565,         790,         111,          16] (sum: 6104)
# Per level average child degree:      [        289,     4.69204,      6.6485,     2.66349,     2.40816,     2.28571] (average: 16.6556)
# Per level codelength for modules:    [0.174834624, 2.312001996, 0.040171084, 0.001558794, 0.000227444, 0.000000000] (sum: 2.528793942)
# Per level codelength for leaf nodes: [0.000000000, 0.024773971, 3.865847624, 0.124603364, 0.010014779, 0.000688630] (sum: 4.025928368)
# Per level codelength total:          [0.174834624, 2.336775967, 3.906018707, 0.126162157, 0.010242224, 0.000688630] (sum: 6.554722310)
#
# ===================================================
#   Infomap ends at 2024-11-29 20:17:16
#   (Elapsed time: 0.127974417s)
# ===================================================
# =======================================================
#   Infomap v2.8.0 starts at 2024-11-29 20:18:31
#   -> Input network:
#   -> No file output!
#   -> Configuration: directed
# =======================================================
#   -> Ordinary network input, using the Map Equation for first order network flows
# Calculating global network flow using flow model 'directed'...
#   -> Using unrecorded teleportation to links.
#   -> PageRank calculation done in 200 iterations.
#
#   => Sum node flow: 1, sum link flow: 1
# Build internal network with 6395 nodes and 16098 links...
#   -> One-level codelength: 10.9499026
#
# ================================================
# Trial 1/1 starting at 2024-11-29 20:18:31
# ================================================
# Two-level compression: 37% 0.56% 0.0243277934% 0.0335601388% 0.00321690087%
# Partitioned to codelength 2.4484979 + 4.36486159 = 6.813359488 in 887 modules.
# Super-level compression: 2.29810879% to codelength 6.656781075 in 291 top modules.
#
# Recursive sub-structure compression: 27.2523311% 0.197387928% 0.0157029842% 0.000730229699% 0% . Found 6 levels with codelength 6.59743787
#
# => Trial 1/1 finished in 0.1368215s with codelength 6.59743787
#
#
# ================================================
# Summary after 1 trial
# ================================================
# Best end modular solution in 6 levels:
# Per level number of modules:         [        291,         776,         334,          40,           2,           0] (sum: 1443)
# Per level number of leaf nodes:      [          0,         631,        4833,         851,          77,           3] (sum: 6395)
# Per level average child degree:      [        291,     4.83505,     6.65851,     2.66766,       1.975,         1.5] (average: 16.385)
# Per level codelength for modules:    [0.211530373, 2.406405417, 0.046606674, 0.000748582, 0.000000000, 0.000000000] (sum: 2.665291046)
# Per level codelength for leaf nodes: [0.000000000, 0.023118022, 3.751239686, 0.154787968, 0.002831724, 0.000169424] (sum: 3.932146823)
# Per level codelength total:          [0.211530373, 2.429523439, 3.797846359, 0.155536551, 0.002831724, 0.000169424] (sum: 6.597437870)
#
# ===================================================
#   Infomap ends at 2024-11-29 20:18:31
#   (Elapsed time: 0.149939125s)
# ===================================================
# =======================================================
#   Infomap v2.8.0 starts at 2024-11-29 20:19:54
#   -> Input network:
#   -> No file output!
#   -> Configuration: directed
# =======================================================
#   -> Ordinary network input, using the Map Equation for first order network flows
# Calculating global network flow using flow model 'directed'...
#   -> Using unrecorded teleportation to links.
#   -> PageRank calculation done in 200 iterations.
#
#   => Sum node flow: 1, sum link flow: 1
# Build internal network with 6566 nodes and 16913 links...
#   -> One-level codelength: 11.0056205
#
# ================================================
# Trial 1/1 starting at 2024-11-29 20:19:54
# ================================================
# Two-level compression: 37% 0.57% 0.0459640511% 0.0032269449% 0.00696383361%
# Partitioned to codelength 2.60500792 + 4.31701619 = 6.922024108 in 876 (874 non-trivial) modules.
# Super-level compression: 2.24082827% to codelength 6.766913435 in 274 top modules.
#
# Recursive sub-structure compression: 23.662441% 0.23372822% 0.0172363498% 0.00015423458% 0% . Found 6 levels with codelength 6.69280183
#
# => Trial 1/1 finished in 0.137053625s with codelength 6.69280183
#
#
# ================================================
# Summary after 1 trial
# ================================================
# Best end modular solution in 6 levels:
# Per level number of modules:         [        274,         877,         311,          40,           2,           0] (sum: 1504)
# Per level number of leaf nodes:      [          0,         576,        5166,         746,          75,           3] (sum: 6566)
# Per level average child degree:      [        274,     5.30292,     6.24515,     2.52733,       1.925,         1.5] (average: 14.7615)
# Per level codelength for modules:    [0.427870490, 2.353532579, 0.029838057, 0.000427060, 0.000000000, 0.000000000] (sum: 2.811668185)
# Per level codelength for leaf nodes: [0.000000000, 0.020307315, 3.756134649, 0.099840675, 0.004823657, 0.000027349] (sum: 3.881133645)
# Per level codelength total:          [0.427870490, 2.373839894, 3.785972705, 0.100267735, 0.004823657, 0.000027349] (sum: 6.692801830)
#
# ===================================================
#   Infomap ends at 2024-11-29 20:19:54
#   (Elapsed time: 0.15126825s)
# ===================================================
# =======================================================
#   Infomap v2.8.0 starts at 2024-11-29 20:21:27
#   -> Input network:
#   -> No file output!
#   -> Configuration: directed
# =======================================================
#   -> Ordinary network input, using the Map Equation for first order network flows
# Calculating global network flow using flow model 'directed'...
#   -> Using unrecorded teleportation to links.
#   -> PageRank calculation done in 200 iterations.
#
#   => Sum node flow: 1, sum link flow: 1
# Build internal network with 6833 nodes and 17813 links...
#   -> One-level codelength: 11.0741348
#
# ================================================
# Trial 1/1 starting at 2024-11-29 20:21:27
# ================================================
# Two-level compression: 37% 0.49% 0.107646158% 0.00184975935% 0.028336798% 0.00331560737%
# Partitioned to codelength 2.54358287 + 4.43865453 = 6.982237406 in 901 (900 non-trivial) modules.
# Super-level compression: 2.27004869% to codelength 6.823737218 in 288 top modules.
#
# Recursive sub-structure compression: 26.3342967% 0.234250272% 0.00508701194% 0% . Found 5 levels with codelength 6.765591459
#
# => Trial 1/1 finished in 0.157814667s with codelength 6.76559146
#
#
# ================================================
# Summary after 1 trial
# ================================================
# Best end modular solution in 5 levels:
# Per level number of modules:         [        288,         848,         303,          37,           0] (sum: 1476)
# Per level number of leaf nodes:      [          0,         612,        5414,         737,          70] (sum: 6833)
# Per level average child degree:      [        288,     5.06944,     6.74175,     2.55446,     1.89189] (average: 15.7657)
# Per level codelength for modules:    [0.255673551, 2.420652719, 0.030223473, 0.000465177, 0.000000000] (sum: 2.707014920)
# Per level codelength for leaf nodes: [0.000000000, 0.018382313, 3.929797789, 0.108427176, 0.001969260] (sum: 4.058576538)
# Per level codelength total:          [0.255673551, 2.439035032, 3.960021263, 0.108892353, 0.001969260] (sum: 6.765591459)
#
# ===================================================
#   Infomap ends at 2024-11-29 20:21:27
#   (Elapsed time: 0.171779334s)
# ===================================================
# =======================================================
#   Infomap v2.8.0 starts at 2024-11-29 20:23:02
#   -> Input network:
#   -> No file output!
#   -> Configuration: directed
# =======================================================
#   -> Ordinary network input, using the Map Equation for first order network flows
# Calculating global network flow using flow model 'directed'...
#   -> Using unrecorded teleportation to links.
#   -> PageRank calculation done in 200 iterations.
#
#   => Sum node flow: 1, sum link flow: 1
# Build internal network with 7007 nodes and 18531 links...
#   -> One-level codelength: 11.1061603
#
# ================================================
# Trial 1/1 starting at 2024-11-29 20:23:02
# ================================================
# Two-level compression: 36% 0.7% 0.0618815775% 0.089603575% 0.00282727565%
# Partitioned to codelength 2.49625594 + 4.55822143 = 7.054477376 in 896 (893 non-trivial) modules.
# Super-level compression: 1.89412509% 0.000275514941% to codelength 6.920837681 in 264 top modules.
#
# Recursive sub-structure compression: 17.2605682% 23.479577% 0.278088824% 0.018750177% 0.00028014765% 0.00021209914% 0% . Found 8 levels with codelength 6.853120941
#
# => Trial 1/1 finished in 0.204911917s with codelength 6.85312094
#
#
# ================================================
# Summary after 1 trial
# ================================================
# Best end modular solution in 8 levels:
# Per level number of modules:         [        264,          54,         847,         331,          49,           2,           2,           0] (sum: 1549)
# Per level number of leaf nodes:      [          0,         595,          67,        5419,         822,         100,           1,           3] (sum: 7007)
# Per level average child degree:      [        264,     2.45833,     16.9259,     6.78867,     2.63142,     2.08163,         1.5,         1.5] (average: 14.9965)
# Per level codelength for modules:    [0.000124648, 0.431797020, 2.323618230, 0.035802821, 0.000880584, 0.000000000, 0.000024606, 0.000000000] (sum: 2.792247909)
# Per level codelength for leaf nodes: [0.000000000, 0.014214498, 0.011313229, 3.906432629, 0.123960148, 0.004919749, 0.000000000, 0.000032779] (sum: 4.060873033)
# Per level codelength total:          [0.000124648, 0.446011518, 2.334931459, 3.942235451, 0.124840733, 0.004919749, 0.000024606, 0.000032779] (sum: 6.853120941)
#
# ===================================================
#   Infomap ends at 2024-11-29 20:23:02
#   (Elapsed time: 0.218295084s)
# ===================================================
# =======================================================
#   Infomap v2.8.0 starts at 2024-11-29 20:24:32
#   -> Input network:
#   -> No file output!
#   -> Configuration: directed
# =======================================================
#   -> Ordinary network input, using the Map Equation for first order network flows
# Calculating global network flow using flow model 'directed'...
#   -> Using unrecorded teleportation to links.
#   -> PageRank calculation done in 200 iterations.
#
#   => Sum node flow: 1, sum link flow: 1
# Build internal network with 7158 nodes and 19030 links...
#   -> One-level codelength: 11.1226384
#
# ================================================
# Trial 1/1 starting at 2024-11-29 20:24:32
# ================================================
# Two-level compression: 36% 0.57% 0.0557722081% 0.00367428368% 0.00179698407%
# Partitioned to codelength 2.62200139 + 4.49425301 = 7.116254397 in 927 (924 non-trivial) modules.
# Super-level compression: 1.98436497% to codelength 6.975041938 in 294 top modules.
#
# Recursive sub-structure compression: 26.1844501% 0.260515423% 0.00807179212% 0.000361016998% 0% . Found 6 levels with codelength 6.897628439
#
# => Trial 1/1 finished in 0.148265875s with codelength 6.89762844
#
#
# ================================================
# Summary after 1 trial
# ================================================
# Best end modular solution in 6 levels:
# Per level number of modules:         [        294,         842,         355,          35,           4,           0] (sum: 1530)
# Per level number of leaf nodes:      [          0,         625,        5532,         931,          64,           6] (sum: 7158)
# Per level average child degree:      [        294,      4.9898,     6.99169,     2.72113,     1.94286,         1.5] (average: 15.8478)
# Per level codelength for modules:    [0.248816881, 2.544378064, 0.051589074, 0.000627734, 0.000023794, 0.000000000] (sum: 2.845435547)
# Per level codelength for leaf nodes: [0.000000000, 0.016865095, 3.874361007, 0.158080572, 0.002830727, 0.000055491] (sum: 4.052192892)
# Per level codelength total:          [0.248816881, 2.561243159, 3.925950081, 0.158708306, 0.002854521, 0.000055491] (sum: 6.897628439)
#
# ===================================================
#   Infomap ends at 2024-11-29 20:24:32
#   (Elapsed time: 0.161915042s)
# ===================================================
# =======================================================
#   Infomap v2.8.0 starts at 2024-11-29 20:26:10
#   -> Input network:
#   -> No file output!
#   -> Configuration: directed
# =======================================================
#   -> Ordinary network input, using the Map Equation for first order network flows
# Calculating global network flow using flow model 'directed'...
#   -> Using unrecorded teleportation to links.
#   -> PageRank calculation done in 200 iterations.
#
#   => Sum node flow: 1, sum link flow: 1
# Build internal network with 7338 nodes and 19641 links...
#   -> One-level codelength: 11.1545592
#
# ================================================
# Trial 1/1 starting at 2024-11-29 20:26:10
# ================================================
# Two-level compression: 36% 0.39% 0.0832819168% 0.0134717211% 0.00762212281%
# Partitioned to codelength 2.60202189 + 4.52374474 = 7.125766633 in 935 (934 non-trivial) modules.
# Super-level compression: 1.97451365% to codelength 6.985067399 in 301 top modules.
#
# Recursive sub-structure compression: 26.3284903% 0.33141233% 0.00468234748% 0.000150434286% 0% . Found 6 levels with codelength 6.919539021
#
# => Trial 1/1 finished in 0.153471291s with codelength 6.91953902
#
#
# ================================================
# Summary after 1 trial
# ================================================
# Best end modular solution in 6 levels:
# Per level number of modules:         [        301,         863,         403,          35,           2,           0] (sum: 1604)
# Per level number of leaf nodes:      [          0,         623,        5527,        1121,          64,           3] (sum: 7338)
# Per level average child degree:      [        301,     4.93688,     6.87138,     2.86849,     1.88571,         1.5] (average: 15.8946)
# Per level codelength for modules:    [0.253484944, 2.552440841, 0.071979853, 0.000581868, 0.000000000, 0.000000000] (sum: 2.878487506)
# Per level codelength for leaf nodes: [0.000000000, 0.017374832, 3.811409112, 0.209664365, 0.002580370, 0.000022836] (sum: 4.041051515)
# Per level codelength total:          [0.253484944, 2.569815673, 3.883388965, 0.210246233, 0.002580370, 0.000022836] (sum: 6.919539021)
#
# ===================================================
#   Infomap ends at 2024-11-29 20:26:10
#   (Elapsed time: 0.167719583s)
# ===================================================
# =======================================================
#   Infomap v2.8.0 starts at 2024-11-29 20:27:49
#   -> Input network:
#   -> No file output!
#   -> Configuration: directed
# =======================================================
#   -> Ordinary network input, using the Map Equation for first order network flows
# Calculating global network flow using flow model 'directed'...
#   -> Using unrecorded teleportation to links.
#   -> PageRank calculation done in 200 iterations.
#
#   => Sum node flow: 1, sum link flow: 1
# Build internal network with 7485 nodes and 20190 links...
#   -> One-level codelength: 11.1745509
#
# ================================================
# Trial 1/1 starting at 2024-11-29 20:27:49
# ================================================
# Two-level compression: 36% 0.41% 0.0283200371% 0.0706961093%
# Partitioned to codelength 2.58536197 + 4.58260589 = 7.167967861 in 941 modules.
# Super-level compression: 1.55519975% to codelength 7.056491643 in 306 top modules.
#
# Recursive sub-structure compression: 24.3592948% 0.239675261% 0.011108546% 0.000143677701% 0% . Found 6 levels with codelength 6.978092359
#
# => Trial 1/1 finished in 0.145714334s with codelength 6.97809236
#
#
# ================================================
# Summary after 1 trial
# ================================================
# Best end modular solution in 6 levels:
# Per level number of modules:         [        306,         907,         350,          39,           2,           0] (sum: 1604)
# Per level number of leaf nodes:      [          0,         628,        5855,         915,          84,           3] (sum: 7485)
# Per level average child degree:      [        306,     5.01634,     6.84123,     2.72571,     2.20513,         1.5] (average: 16.1272)
# Per level codelength for modules:    [0.337304557, 2.425787057, 0.044704134, 0.000930524, 0.000000000, 0.000000000] (sum: 2.808726272)
# Per level codelength for leaf nodes: [0.000000000, 0.015191831, 4.003347885, 0.145514762, 0.005289614, 0.000021995] (sum: 4.169366087)
# Per level codelength total:          [0.337304557, 2.440978888, 4.048052019, 0.146445287, 0.005289614, 0.000021995] (sum: 6.978092359)
#
# ===================================================
#   Infomap ends at 2024-11-29 20:27:49
#   (Elapsed time: 0.159854042s)
# ===================================================
# =======================================================
#   Infomap v2.8.0 starts at 2024-11-29 20:29:33
#   -> Input network:
#   -> No file output!
#   -> Configuration: directed
# =======================================================
#   -> Ordinary network input, using the Map Equation for first order network flows
# Calculating global network flow using flow model 'directed'...
#   -> Using unrecorded teleportation to links.
#   -> PageRank calculation done in 200 iterations.
#
#   => Sum node flow: 1, sum link flow: 1
# Build internal network with 7575 nodes and 20627 links...
#   -> One-level codelength: 11.1980843
#
# ================================================
# Trial 1/1 starting at 2024-11-29 20:29:33
# ================================================
# Two-level compression: 35% 0.5%
# Partitioned to codelength 2.57824492 + 4.61963159 = 7.197876512 in 947 (945 non-trivial) modules.
# Super-level compression: 1.40277094% to codelength 7.096906793 in 308 top modules.
#
# Recursive sub-structure compression: 23.7622228% 0.424345605% 0.00743214821% 0.000193823228% 0% . Found 6 levels with codelength 7.014968841
#
# => Trial 1/1 finished in 0.125239875s with codelength 7.01496884
#
#
# ================================================
# Summary after 1 trial
# ================================================
# Best end modular solution in 6 levels:
# Per level number of modules:         [        308,         882,         397,          50,           4,           0] (sum: 1641)
# Per level number of leaf nodes:      [          0,         614,        5730,        1128,          97,           6] (sum: 7575)
# Per level average child degree:      [        308,     4.85714,     6.94671,     2.96725,        2.02,         1.5] (average: 16.1026)
# Per level codelength for modules:    [0.351501080, 2.479918162, 0.060413631, 0.000827307, 0.000000000, 0.000000000] (sum: 2.892660181)
# Per level codelength for leaf nodes: [0.000000000, 0.016162395, 3.909950750, 0.191679804, 0.004465854, 0.000049857] (sum: 4.122308659)
# Per level codelength total:          [0.351501080, 2.496080557, 3.970364381, 0.192507111, 0.004465854, 0.000049857] (sum: 7.014968841)
#
# ===================================================
#   Infomap ends at 2024-11-29 20:29:33
#   (Elapsed time: 0.141200042s)
# ===================================================
# =======================================================
#   Infomap v2.8.0 starts at 2024-11-29 20:31:26
#   -> Input network:
#   -> No file output!
#   -> Configuration: directed
# =======================================================
#   -> Ordinary network input, using the Map Equation for first order network flows
# Calculating global network flow using flow model 'directed'...
#   -> Using unrecorded teleportation to links.
#   -> PageRank calculation done in 200 iterations.
#
#   => Sum node flow: 1, sum link flow: 1
# Build internal network with 7650 nodes and 21013 links...
#   -> One-level codelength: 11.212325
#
# ================================================
# Trial 1/1 starting at 2024-11-29 20:31:26
# ================================================
# Two-level compression: 35% 0.62% 0.0271228817% 0.0158467062%
# Partitioned to codelength 2.67114254 + 4.58680461 = 7.257947147 in 954 (953 non-trivial) modules.
# Super-level compression: 1.95507769% to codelength 7.116048641 in 311 top modules.
#
# Recursive sub-structure compression: 25.1340647% 0.276220231% 0.00900668188% 0.000439706535% 0% . Found 6 levels with codelength 7.051216972
#
# => Trial 1/1 finished in 0.16449s with codelength 7.05121697
#
#
# ================================================
# Summary after 1 trial
# ================================================
# Best end modular solution in 6 levels:
# Per level number of modules:         [        311,         869,         338,          41,           4,           0] (sum: 1563)
# Per level number of leaf nodes:      [          0,         651,        5994,         921,          77,           7] (sum: 7650)
# Per level average child degree:      [        311,     4.88746,     7.28654,     2.84615,     1.97561,        1.75] (average: 16.6285)
# Per level codelength for modules:    [0.241767852, 2.609558867, 0.047027655, 0.000664793, 0.000000000, 0.000000000] (sum: 2.899019167)
# Per level codelength for leaf nodes: [0.000000000, 0.017074834, 3.981520808, 0.149601639, 0.003873151, 0.000127373] (sum: 4.152197804)
# Per level codelength total:          [0.241767852, 2.626633701, 4.028548463, 0.150266432, 0.003873151, 0.000127373] (sum: 7.051216972)
#
# ===================================================
#   Infomap ends at 2024-11-29 20:31:26
#   (Elapsed time: 0.181715958s)
# ===================================================
# =======================================================
#   Infomap v2.8.0 starts at 2024-11-29 20:33:18
#   -> Input network:
#   -> No file output!
#   -> Configuration: directed
# =======================================================
#   -> Ordinary network input, using the Map Equation for first order network flows
# Calculating global network flow using flow model 'directed'...
#   -> Using unrecorded teleportation to links.
#   -> PageRank calculation done in 200 iterations.
#
#   => Sum node flow: 1, sum link flow: 1
# Build internal network with 7699 nodes and 21295 links...
#   -> One-level codelength: 11.2229976
#
# ================================================
# Trial 1/1 starting at 2024-11-29 20:33:18
# ================================================
# Two-level compression: 35% 0.59% 0.0104272968% 0.00218539049% 0.0133088163%
# Partitioned to codelength 2.61590888 + 4.65324356 = 7.269152444 in 954 (952 non-trivial) modules.
# Super-level compression: 1.39694941% to codelength 7.167606062 in 304 top modules.
#
# Recursive sub-structure compression: 23.2431782% 0.350241723% 0.00561398486% 0.000430136562% 0% . Found 6 levels with codelength 7.103106208
#
# => Trial 1/1 finished in 0.15412525s with codelength 7.10310621
#
#
# ================================================
# Summary after 1 trial
# ================================================
# Best end modular solution in 6 levels:
# Per level number of modules:         [        304,         921,         345,          37,           4,           0] (sum: 1611)
# Per level number of leaf nodes:      [          0,         614,        6070,         942,          66,           7] (sum: 7699)
# Per level average child degree:      [        304,     5.04934,     6.96526,     2.83768,     1.89189,        1.75] (average: 15.8724)
# Per level codelength for modules:    [0.380642406, 2.504543779, 0.052726725, 0.000340211, 0.000000000, 0.000000000] (sum: 2.938253122)
# Per level codelength for leaf nodes: [0.000000000, 0.013923807, 3.978288878, 0.170003241, 0.002511642, 0.000125518] (sum: 4.164853086)
# Per level codelength total:          [0.380642406, 2.518467586, 4.031015603, 0.170343452, 0.002511642, 0.000125518] (sum: 7.103106208)
#
# ===================================================
#   Infomap ends at 2024-11-29 20:33:18
#   (Elapsed time: 0.169567709s)
# ===================================================
#    Year  Community ID  Size  Number of Women  Percentage of Women  \
# 0  2002             1     8                0             0.000000
# 1  2002             2     3                1            33.333333
# 2  2002             3     8                1            12.500000
# 3  2002             4     6                0             0.000000
# 4  2002             5     3                0             0.000000
#
#                                              Members
# 0  Gottfried Wilhelm Leibniz, Isaac Newton, Giord...
# 1          Ada Lovelace, Charles Babbage, Lord Byron
# 2  David Hilbert, Felix Klein, Emmy Noether, Bert...
# 3  Erasmus Darwin, Adam Sedgwick, William Whewell...
# 4  Johann Bernoulli, Leonhard Euler, Daniel Berno...
#    Year  Community ID  Size  Number of Women  Percentage of Women  \
# 0  2004             1   175                5             2.857143
# 1  2004             2    65                1             1.538462
# 2  2005             1   151                7             4.635762
# 3  2005             2   104                5             4.807692
# 4  2005             3    58                1             1.724138
#
#                                              Members
# 0  Arnold Sommerfeld, Werner Heisenberg, Felix Kl...
# 1  Isaac Newton, Johannes Kepler, Gottfried Wilhe...
# 2  Albert Einstein, Bertrand Russell, Moritz Schl...
# 3  Charles Darwin, Alfred Russel Wallace, Adam Se...
# 4  David Hilbert, Felix Klein, Hermann Minkowski,...

# %%
all_communities_data = []
large_communities_data = []

for year in range(2002, 2025):

    df_fr_year = df_fr[df_fr['Year'] == year]
    
    G_fr = gc.create_directed_graph(df_fr_year, gender)

    node_mapping = {node: i for i, node in enumerate(G_fr.nodes())}
    reverse_mapping = {i: node for node, i in node_mapping.items()}
    infomap = Infomap("--directed")
    
    for u, v, data in G_fr.edges(data=True):
        weight = data.get('weight', 1)
        infomap.add_link(node_mapping[u], node_mapping[v], weight)
    
    infomap.run()

    community_summary = {}

    for node in infomap.tree:
        if node.is_leaf:
            original_node = reverse_mapping[node.node_id]
            community_id = node.module_id

            if community_id not in community_summary:
                community_summary[community_id] = {"members": [], "female_count": 0}

            community_summary[community_id]["members"].append(original_node)

            if original_node in G_fr.nodes and "gender" in G_fr.nodes[original_node]:
                gender_value = G_fr.nodes[original_node]["gender"]

                if isinstance(gender_value, pd.Series):
                    if not gender_value.empty:
                        gender_value = gender_value.iloc[0]
                elif isinstance(gender_value, list):
                    gender_value = gender_value[0]

                if gender_value == "f":
                    community_summary[community_id]["female_count"] += 1
    
    community_data = []
    for community_id, data in community_summary.items():
        size = len(data["members"])
        female_count = data["female_count"]
        female_percentage = (female_count / size) * 100 if size > 0 else 0
        members_string = ", ".join(data["members"])
        
        community_data.append({
            "Year": year,
            "Community ID": community_id,
            "Size": size,
            "Number of Women": female_count,
            "Percentage of Women": female_percentage,
            "Members": members_string
        })
    
    all_communities_data.extend(community_data)

all_communities_df = pd.DataFrame(all_communities_data)

all_communities_df.to_csv("all_communities_infomap_fr.csv", sep=";", index=False)
# Out:
# =======================================================
#   Infomap v2.8.0 starts at 2024-11-29 20:39:33
#   -> Input network:
#   -> No file output!
#   -> Configuration: directed
# =======================================================
#   -> Ordinary network input, using the Map Equation for first order network flows
# Calculating global network flow using flow model 'directed'...
#   -> Using unrecorded teleportation to links.
#   -> PageRank calculation done in 200 iterations.
#
#   => Sum node flow: 1, sum link flow: 1
# Build internal network with 13 nodes and 7 links...
#   -> One-level codelength: 2.80735492
#
# ================================================
# Trial 1/1 starting at 2024-11-29 20:39:33
# ================================================
# Two-level compression: 90% 0%
# Partitioned to codelength 0 + 0.285714286 = 0.2857142857 in 6 modules.
# Super-level compression: to codelength 0.2857142857 in 6 top modules.
#
# Recursive sub-structure compression: 0% . Found 2 levels with codelength 0.2857142857
#
# => Trial 1/1 finished in 0.000132584s with codelength 0.285714286
#
#
# ================================================
# Summary after 1 trial
# ================================================
# Best end modular solution in 2 levels:
# Per level number of modules:         [          6,           0] (sum: 6)
# Per level number of leaf nodes:      [          0,          13] (sum: 13)
# Per level average child degree:      [          6,     2.16667] (average: 3.37719)
# Per level codelength for modules:    [0.000000000, 0.000000000] (sum: 0.000000000)
# Per level codelength for leaf nodes: [0.000000000, 0.285714286] (sum: 0.285714286)
# Per level codelength total:          [0.000000000, 0.285714286] (sum: 0.285714286)
#
# ===================================================
#   Infomap ends at 2024-11-29 20:39:33
#   (Elapsed time: 0.00019825s)
# ===================================================
# =======================================================
#   Infomap v2.8.0 starts at 2024-11-29 20:39:34
#   -> Input network:
#   -> No file output!
#   -> Configuration: directed
# =======================================================
#   -> Ordinary network input, using the Map Equation for first order network flows
# Calculating global network flow using flow model 'directed'...
#   -> Using unrecorded teleportation to links.
#   -> PageRank calculation done in 200 iterations.
#
#   => Sum node flow: 1, sum link flow: 1
# Build internal network with 96 nodes and 68 links...
#   -> One-level codelength: 5.35113312
#
# ================================================
# Trial 1/1 starting at 2024-11-29 20:39:34
# ================================================
# Two-level compression: 78% 1.4e-12%
# Partitioned to codelength 0.0314950073 + 1.16471978 = 1.196214785 in 36 modules.
# Super-level compression: 1.1311109% to codelength 1.18268427 in 33 top modules.
#
# Recursive sub-structure compression: 12.2620373% 0% . Found 3 levels with codelength 1.136870951
#
# => Trial 1/1 finished in 0.000819292s with codelength 1.13687095
#
#
# ================================================
# Summary after 1 trial
# ================================================
# Best end modular solution in 3 levels:
# Per level number of modules:         [         33,          10,           0] (sum: 43)
# Per level number of leaf nodes:      [          0,          72,          24] (sum: 96)
# Per level average child degree:      [         33,     2.48485,         2.4] (average: 9.7148)
# Per level codelength for modules:    [0.000000000, 0.042709568, 0.000000000] (sum: 0.042709568)
# Per level codelength for leaf nodes: [0.000000000, 0.772568124, 0.321593259] (sum: 1.094161383)
# Per level codelength total:          [0.000000000, 0.815277692, 0.321593259] (sum: 1.136870951)
#
# ===================================================
#   Infomap ends at 2024-11-29 20:39:34
#   (Elapsed time: 0.000996333s)
# ===================================================
# =======================================================
#   Infomap v2.8.0 starts at 2024-11-29 20:39:36
#   -> Input network:
#   -> No file output!
#   -> Configuration: directed
# =======================================================
#   -> Ordinary network input, using the Map Equation for first order network flows
# Calculating global network flow using flow model 'directed'...
#   -> Using unrecorded teleportation to links.
#   -> PageRank calculation done in 200 iterations.
#
#   => Sum node flow: 1, sum link flow: 1
# Build internal network with 478 nodes and 459 links...
#   -> One-level codelength: 7.73907646
#
# ================================================
# Trial 1/1 starting at 2024-11-29 20:39:36
# ================================================
# Two-level compression: 69% 2.7e-12%
# Partitioned to codelength 0.276360431 + 2.12007046 = 2.396430893 in 126 modules.
# Super-level compression: 5.77360744% 0.286112742% to codelength 2.251609754 in 97 top modules.
#
# Recursive sub-structure compression: 19.1821678% 10.5589414% 11.5976166% 4.36708129% 3.61444142% 0% . Found 7 levels with codelength 2.068635526
#
# => Trial 1/1 finished in 0.007418209s with codelength 2.06863553
#
#
# ================================================
# Summary after 1 trial
# ================================================
# Best end modular solution in 7 levels:
# Per level number of modules:         [         97,          49,          21,          22,          21,           8,           0] (sum: 218)
# Per level number of leaf nodes:      [          0,         198,          95,          44,          70,          43,          28] (sum: 478)
# Per level average child degree:      [         97,     2.54639,     2.36735,     3.14286,     4.13636,     2.42857,         3.5] (average: 15.9745)
# Per level codelength for modules:    [0.000000000, 0.052937951, 0.055622958, 0.106146761, 0.045893315, 0.036506185, 0.000000000] (sum: 0.297107170)
# Per level codelength for leaf nodes: [0.000000000, 0.305988870, 0.270787548, 0.269425784, 0.516647746, 0.176071083, 0.232607326] (sum: 1.771528356)
# Per level codelength total:          [0.000000000, 0.358926821, 0.326410506, 0.375572545, 0.562541061, 0.212577267, 0.232607326] (sum: 2.068635526)
#
# ===================================================
#   Infomap ends at 2024-11-29 20:39:36
#   (Elapsed time: 0.008095583s)
# ===================================================
# =======================================================
#   Infomap v2.8.0 starts at 2024-11-29 20:39:42
#   -> Input network:
#   -> No file output!
#   -> Configuration: directed
# =======================================================
#   -> Ordinary network input, using the Map Equation for first order network flows
# Calculating global network flow using flow model 'directed'...
#   -> Using unrecorded teleportation to links.
#   -> PageRank calculation done in 200 iterations.
#
#   => Sum node flow: 1, sum link flow: 1
# Build internal network with 1179 nodes and 1406 links...
#   -> One-level codelength: 8.75187257
#
# ================================================
# Trial 1/1 starting at 2024-11-29 20:39:42
# ================================================
# Two-level compression: 63% 0.39% 0.0707523747%
# Partitioned to codelength 0.734383716 + 2.50497479 = 3.239358506 in 274 modules.
# Super-level compression: 6.88980812% 0.440629977% to codelength 3.002882758 in 158 top modules.
#
# Recursive sub-structure compression: 32.3481766% 25.3585292% 6.69096955% 1.51390269% 0.1818017% 0% . Found 7 levels with codelength 2.851252502
#
# => Trial 1/1 finished in 0.0211185s with codelength 2.8512525
#
#
# ================================================
# Summary after 1 trial
# ================================================
# Best end modular solution in 7 levels:
# Per level number of modules:         [        158,          45,         142,         118,          50,          13,           0] (sum: 526)
# Per level number of leaf nodes:      [          0,         355,          46,         382,         261,         109,          26] (sum: 1179)
# Per level average child degree:      [        158,     2.53165,     4.17778,     3.52113,     2.63559,        2.44,           2] (average: 17.4147)
# Per level codelength for modules:    [0.004384752, 0.155562593, 0.419215366, 0.120776522, 0.032497017, 0.011088786, 0.000000000] (sum: 0.743525036)
# Per level codelength for leaf nodes: [0.000000000, 0.213913048, 0.031064211, 1.275493415, 0.431695075, 0.128118456, 0.027443262] (sum: 2.107727466)
# Per level codelength total:          [0.004384752, 0.369475641, 0.450279577, 1.396269938, 0.464192092, 0.139207241, 0.027443262] (sum: 2.851252502)
#
# ===================================================
#   Infomap ends at 2024-11-29 20:39:42
#   (Elapsed time: 0.022956333s)
# ===================================================
# =======================================================
#   Infomap v2.8.0 starts at 2024-11-29 20:39:50
#   -> Input network:
#   -> No file output!
#   -> Configuration: directed
# =======================================================
#   -> Ordinary network input, using the Map Equation for first order network flows
# Calculating global network flow using flow model 'directed'...
#   -> Using unrecorded teleportation to links.
#   -> PageRank calculation done in 200 iterations.
#
#   => Sum node flow: 1, sum link flow: 1
# Build internal network with 1819 nodes and 2385 links...
#   -> One-level codelength: 9.27682269
#
# ================================================
# Trial 1/1 starting at 2024-11-29 20:39:50
# ================================================
# Two-level compression: 61% 0.19% 0.158011997%
# Partitioned to codelength 0.961984419 + 2.6524011 = 3.614385521 in 406 modules.
# Super-level compression: 5.96410314% 0.384588289% to codelength 3.385748378 in 207 top modules.
#
# Recursive sub-structure compression: 30.0424983% 26.2949641% 5.89740087% 2.48691257% 0.320713571% 0.0133197674% 0.0036211679% 0% . Found 9 levels with codelength 3.223985602
#
# => Trial 1/1 finished in 0.033188292s with codelength 3.2239856
#
#
# ================================================
# Summary after 1 trial
# ================================================
# Best end modular solution in 9 levels:
# Per level number of modules:         [        207,          76,         239,         166,          79,          33,           4,           2,           0] (sum: 806)
# Per level number of leaf nodes:      [          0,         429,          99,         680,         363,         154,          87,           4,           3] (sum: 1819)
# Per level average child degree:      [        207,     2.43961,     4.44737,     3.53975,     2.66265,     2.36709,     2.75758,         1.5,         1.5] (average: 19.2239)
# Per level codelength for modules:    [0.014109335, 0.226678784, 0.588093028, 0.126078280, 0.039765877, 0.008644048, 0.000000000, 0.000309318, 0.000000000] (sum: 1.003678669)
# Per level codelength for leaf nodes: [0.000000000, 0.124689835, 0.058435822, 1.396510961, 0.448323656, 0.135032010, 0.055524032, 0.001790617, 0.000000000] (sum: 2.220306933)
# Per level codelength total:          [0.014109335, 0.351368619, 0.646528850, 1.522589240, 0.488089532, 0.143676058, 0.055524032, 0.002099935, 0.000000000] (sum: 3.223985602)
#
# ===================================================
#   Infomap ends at 2024-11-29 20:39:50
#   (Elapsed time: 0.037003041s)
# ===================================================
# =======================================================
#   Infomap v2.8.0 starts at 2024-11-29 20:40:00
#   -> Input network:
#   -> No file output!
#   -> Configuration: directed
# =======================================================
#   -> Ordinary network input, using the Map Equation for first order network flows
# Calculating global network flow using flow model 'directed'...
#   -> Using unrecorded teleportation to links.
#   -> PageRank calculation done in 200 iterations.
#
#   => Sum node flow: 1, sum link flow: 1
# Build internal network with 2338 nodes and 3579 links...
#   -> One-level codelength: 9.65606443
#
# ================================================
# Trial 1/1 starting at 2024-11-29 20:40:00
# ================================================
# Two-level compression: 55% 0.33% 0.14339868% 0.00430381891% 0.0371769138%
# Partitioned to codelength 1.2869077 + 3.03518614 = 4.32209384 in 476 (474 non-trivial) modules.
# Super-level compression: 5.37251206% to codelength 4.089888827 in 234 top modules.
#
# Recursive sub-structure compression: 31.4395661% 3.06338002% 0.186788675% 0.00853830151% 0% . Found 6 levels with codelength 3.994314167
#
# => Trial 1/1 finished in 0.039164541s with codelength 3.99431417
#
#
# ================================================
# Summary after 1 trial
# ================================================
# Best end modular solution in 6 levels:
# Per level number of modules:         [        234,         344,         209,          37,           4,           0] (sum: 828)
# Per level number of leaf nodes:      [          0,         459,        1270,         515,          85,           9] (sum: 2338)
# Per level average child degree:      [        234,     3.43162,     4.29942,     2.64115,     2.40541,        2.25] (average: 20.7084)
# Per level codelength for modules:    [0.224549983, 0.988651935, 0.139324303, 0.006612682, 0.000000000, 0.000000000] (sum: 1.359138903)
# Per level codelength for leaf nodes: [0.000000000, 0.111137094, 2.077888338, 0.398959764, 0.044814676, 0.002375392] (sum: 2.635175264)
# Per level codelength total:          [0.224549983, 1.099789030, 2.217212641, 0.405572446, 0.044814676, 0.002375392] (sum: 3.994314167)
#
# ===================================================
#   Infomap ends at 2024-11-29 20:40:00
#   (Elapsed time: 0.042599167s)
# ===================================================
# =======================================================
#   Infomap v2.8.0 starts at 2024-11-29 20:40:12
#   -> Input network:
#   -> No file output!
#   -> Configuration: directed
# =======================================================
#   -> Ordinary network input, using the Map Equation for first order network flows
# Calculating global network flow using flow model 'directed'...
#   -> Using unrecorded teleportation to links.
#   -> PageRank calculation done in 200 iterations.
#
#   => Sum node flow: 1, sum link flow: 1
# Build internal network with 2729 nodes and 4542 links...
#   -> One-level codelength: 9.90003715
#
# ================================================
# Trial 1/1 starting at 2024-11-29 20:40:12
# ================================================
# Two-level compression: 52% 0.47%
# Partitioned to codelength 1.44750149 + 3.27081882 = 4.718320306 in 512 (509 non-trivial) modules.
# Super-level compression: 4.21459623% to codelength 4.519462156 in 228 top modules.
#
# Recursive sub-structure compression: 31.2897414% 1.01639704% 0.0785498965% 0% . Found 5 levels with codelength 4.425356785
#
# => Trial 1/1 finished in 0.037665791s with codelength 4.42535679
#
#
# ================================================
# Summary after 1 trial
# ================================================
# Best end modular solution in 5 levels:
# Per level number of modules:         [        228,         419,         238,          35,           0] (sum: 920)
# Per level number of leaf nodes:      [          0,         443,        1655,         563,          68] (sum: 2729)
# Per level average child degree:      [        228,      3.7807,      4.5179,     2.51261,     1.94286] (average: 17.9309)
# Per level codelength for modules:    [0.277721752, 1.216166244, 0.066845679, 0.001993219, 0.000000000] (sum: 1.562726894)
# Per level codelength for leaf nodes: [0.000000000, 0.063906546, 2.492027948, 0.291779291, 0.014916106] (sum: 2.862629891)
# Per level codelength total:          [0.277721752, 1.280072790, 2.558873627, 0.293772511, 0.014916106] (sum: 4.425356785)
#
# ===================================================
#   Infomap ends at 2024-11-29 20:40:12
#   (Elapsed time: 0.04175775s)
# ===================================================
# =======================================================
#   Infomap v2.8.0 starts at 2024-11-29 20:40:26
#   -> Input network:
#   -> No file output!
#   -> Configuration: directed
# =======================================================
#   -> Ordinary network input, using the Map Equation for first order network flows
# Calculating global network flow using flow model 'directed'...
#   -> Using unrecorded teleportation to links.
#   -> PageRank calculation done in 200 iterations.
#
#   => Sum node flow: 1, sum link flow: 1
# Build internal network with 2954 nodes and 5239 links...
#   -> One-level codelength: 10.0180332
#
# ================================================
# Trial 1/1 starting at 2024-11-29 20:40:26
# ================================================
# Two-level compression: 51% 0.35% 0.101746444% 0.00471436093% 0.00866587809%
# Partitioned to codelength 1.53587062 + 3.38641964 = 4.92229026 in 516 (513 non-trivial) modules.
# Super-level compression: 4.00942651% to codelength 4.724934649 in 225 top modules.
#
# Recursive sub-structure compression: 29.3331137% 0.681256543% 0.065249815% 0% . Found 5 levels with codelength 4.628458862
#
# => Trial 1/1 finished in 0.048803125s with codelength 4.62845886
#
#
# ================================================
# Summary after 1 trial
# ================================================
# Best end modular solution in 5 levels:
# Per level number of modules:         [        225,         457,         222,          30,           0] (sum: 934)
# Per level number of leaf nodes:      [          0,         442,        1901,         545,          66] (sum: 2954)
# Per level average child degree:      [        225,     3.99556,     4.64551,     2.59009,         2.2] (average: 16.9017)
# Per level codelength for modules:    [0.316790288, 1.272021123, 0.063549352, 0.001253528, 0.000000000] (sum: 1.653614291)
# Per level codelength for leaf nodes: [0.000000000, 0.058274239, 2.625164610, 0.279131854, 0.012273870] (sum: 2.974844571)
# Per level codelength total:          [0.316790288, 1.330295361, 2.688713962, 0.280385382, 0.012273870] (sum: 4.628458862)
#
# ===================================================
#   Infomap ends at 2024-11-29 20:40:26
#   (Elapsed time: 0.053289917s)
# ===================================================
# =======================================================
#   Infomap v2.8.0 starts at 2024-11-29 20:40:43
#   -> Input network:
#   -> No file output!
#   -> Configuration: directed
# =======================================================
#   -> Ordinary network input, using the Map Equation for first order network flows
# Calculating global network flow using flow model 'directed'...
#   -> Using unrecorded teleportation to links.
#   -> PageRank calculation done in 200 iterations.
#
#   => Sum node flow: 1, sum link flow: 1
# Build internal network with 3208 nodes and 5888 links...
#   -> One-level codelength: 10.1424878
#
# ================================================
# Trial 1/1 starting at 2024-11-29 20:40:43
# ================================================
# Two-level compression: 49% 0.42% 0.12846539% 0.0183603351%
# Partitioned to codelength 1.68574373 + 3.4920412 = 5.177784927 in 540 (538 non-trivial) modules.
# Super-level compression: 4.19901027% to codelength 4.960369206 in 223 top modules.
#
# Recursive sub-structure compression: 27.5674923% 7.23569803% 0.328549121% 0.0160232019% 0.00236425061% 0% . Found 7 levels with codelength 4.85444328
#
# => Trial 1/1 finished in 0.053454584s with codelength 4.85444328
#
#
# ================================================
# Summary after 1 trial
# ================================================
# Best end modular solution in 7 levels:
# Per level number of modules:         [        223,         415,         281,          68,           8,           2,           0] (sum: 997)
# Per level number of leaf nodes:      [          0,         441,        1711,         876,         163,          13,           4] (sum: 3208)
# Per level average child degree:      [        223,     3.83857,         4.8,     3.35943,     2.51471,       1.875,           2] (average: 15.7465)
# Per level codelength for modules:    [0.275085183, 1.279981359, 0.283189077, 0.007241086, 0.001617185, 0.000194291, 0.000000000] (sum: 1.847308181)
# Per level codelength for leaf nodes: [0.000000000, 0.052824529, 2.125523181, 0.764047704, 0.060021410, 0.004459448, 0.000258827] (sum: 3.007135100)
# Per level codelength total:          [0.275085183, 1.332805889, 2.408712258, 0.771288790, 0.061638595, 0.004653739, 0.000258827] (sum: 4.854443280)
#
# ===================================================
#   Infomap ends at 2024-11-29 20:40:43
#   (Elapsed time: 0.058289459s)
# ===================================================
# =======================================================
#   Infomap v2.8.0 starts at 2024-11-29 20:41:02
#   -> Input network:
#   -> No file output!
#   -> Configuration: directed
# =======================================================
#   -> Ordinary network input, using the Map Equation for first order network flows
# Calculating global network flow using flow model 'directed'...
#   -> Using unrecorded teleportation to links.
#   -> PageRank calculation done in 200 iterations.
#
#   => Sum node flow: 1, sum link flow: 1
# Build internal network with 3445 nodes and 6441 links...
#   -> One-level codelength: 10.1720162
#
# ================================================
# Trial 1/1 starting at 2024-11-29 20:41:02
# ================================================
# Two-level compression: 49% 0.38% 0.0138281558% 0.00286647049% 0.00419036116%
# Partitioned to codelength 1.66900231 + 3.51982914 = 5.188831445 in 581 modules.
# Super-level compression: 3.50268664% to codelength 5.00708294 in 232 top modules.
#
# Recursive sub-structure compression: 28.6834255% 0.556489611% 0.0163553906% 0.00406364189% 0% . Found 6 levels with codelength 4.900873482
#
# => Trial 1/1 finished in 0.090119292s with codelength 4.90087348
#
#
# ================================================
# Summary after 1 trial
# ================================================
# Best end modular solution in 6 levels:
# Per level number of modules:         [        232,         558,         223,          21,           5,           0] (sum: 1039)
# Per level number of leaf nodes:      [          0,         455,        2441,         498,          39,          12] (sum: 3445)
# Per level average child degree:      [        232,     4.36638,     4.77419,     2.32735,     2.09524,         2.4] (average: 16.1228)
# Per level codelength for modules:    [0.373109124, 1.431798920, 0.034069531, 0.000735505, 0.000479682, 0.000000000] (sum: 1.840192763)
# Per level codelength for leaf nodes: [0.000000000, 0.055917733, 2.830184312, 0.168616138, 0.005016951, 0.000945586] (sum: 3.060680720)
# Per level codelength total:          [0.373109124, 1.487716653, 2.864253843, 0.169351643, 0.005496633, 0.000945586] (sum: 4.900873482)
#
# ===================================================
#   Infomap ends at 2024-11-29 20:41:02
#   (Elapsed time: 0.095541792s)
# ===================================================
# =======================================================
#   Infomap v2.8.0 starts at 2024-11-29 20:41:24
#   -> Input network:
#   -> No file output!
#   -> Configuration: directed
# =======================================================
#   -> Ordinary network input, using the Map Equation for first order network flows
# Calculating global network flow using flow model 'directed'...
#   -> Using unrecorded teleportation to links.
#   -> PageRank calculation done in 200 iterations.
#
#   => Sum node flow: 1, sum link flow: 1
# Build internal network with 3694 nodes and 7132 links...
#   -> One-level codelength: 10.2693403
#
# ================================================
# Trial 1/1 starting at 2024-11-29 20:41:24
# ================================================
# Two-level compression: 47% 0.43% 0.0538794068% 0.00232972705% 0.00546156213%
# Partitioned to codelength 1.75691792 + 3.61483441 = 5.371752338 in 616 (615 non-trivial) modules.
# Super-level compression: 3.33201159% to codelength 5.192764927 in 250 top modules.
#
# Recursive sub-structure compression: 26.986515% 3.79534502% 0.0661969195% 0.00174713302% 0% . Found 6 levels with codelength 5.091468615
#
# => Trial 1/1 finished in 0.066425417s with codelength 5.09146861
#
#
# ================================================
# Summary after 1 trial
# ================================================
# Best end modular solution in 6 levels:
# Per level number of modules:         [        250,         484,         287,          72,           2,           0] (sum: 1095)
# Per level number of leaf nodes:      [          0,         495,        2183,         848,         164,           4] (sum: 3694)
# Per level average child degree:      [        250,       3.916,     5.10331,     3.20557,     2.30556,           2] (average: 17.1808)
# Per level codelength for modules:    [0.343182929, 1.456923248, 0.188049520, 0.006925624, 0.000150587, 0.000000000] (sum: 1.995231909)
# Per level codelength for leaf nodes: [0.000000000, 0.049627233, 2.512066668, 0.507152901, 0.027189298, 0.000200605] (sum: 3.096236706)
# Per level codelength total:          [0.343182929, 1.506550481, 2.700116188, 0.514078525, 0.027339885, 0.000200605] (sum: 5.091468615)
#
# ===================================================
#   Infomap ends at 2024-11-29 20:41:25
#   (Elapsed time: 0.072345042s)
# ===================================================
# =======================================================
#   Infomap v2.8.0 starts at 2024-11-29 20:41:50
#   -> Input network:
#   -> No file output!
#   -> Configuration: directed
# =======================================================
#   -> Ordinary network input, using the Map Equation for first order network flows
# Calculating global network flow using flow model 'directed'...
#   -> Using unrecorded teleportation to links.
#   -> PageRank calculation done in 200 iterations.
#
#   => Sum node flow: 1, sum link flow: 1
# Build internal network with 3928 nodes and 7799 links...
#   -> One-level codelength: 10.3938374
#
# ================================================
# Trial 1/1 starting at 2024-11-29 20:41:50
# ================================================
# Two-level compression: 46% 0.49%
# Partitioned to codelength 1.81404635 + 3.76703876 = 5.581085117 in 629 (628 non-trivial) modules.
# Super-level compression: 2.9476771% to codelength 5.41657275 in 247 top modules.
#
# Recursive sub-structure compression: 28.4895712% 0.6876432% 0.0154411808% 0% . Found 5 levels with codelength 5.302955889
#
# => Trial 1/1 finished in 0.0526555s with codelength 5.30295589
#
#
# ================================================
# Summary after 1 trial
# ================================================
# Best end modular solution in 5 levels:
# Per level number of modules:         [        247,         571,         246,          23,           0] (sum: 1087)
# Per level number of leaf nodes:      [          0,         489,        2770,         622,          47] (sum: 3928)
# Per level average child degree:      [        247,      4.2915,     5.28196,     2.62195,     2.04348] (average: 16.6053)
# Per level codelength for modules:    [0.366349968, 1.608259102, 0.065204715, 0.001045302, 0.000000000] (sum: 2.040859087)
# Per level codelength for leaf nodes: [0.000000000, 0.044279085, 2.980567644, 0.233130133, 0.004119940] (sum: 3.262096802)
# Per level codelength total:          [0.366349968, 1.652538187, 3.045772360, 0.234175435, 0.004119940] (sum: 5.302955889)
#
# ===================================================
#   Infomap ends at 2024-11-29 20:41:50
#   (Elapsed time: 0.058993125s)
# ===================================================
# =======================================================
#   Infomap v2.8.0 starts at 2024-11-29 20:42:17
#   -> Input network:
#   -> No file output!
#   -> Configuration: directed
# =======================================================
#   -> Ordinary network input, using the Map Equation for first order network flows
# Calculating global network flow using flow model 'directed'...
#   -> Using unrecorded teleportation to links.
#   -> PageRank calculation done in 200 iterations.
#
#   => Sum node flow: 1, sum link flow: 1
# Build internal network with 4078 nodes and 8371 links...
#   -> One-level codelength: 10.48447
#
# ================================================
# Trial 1/1 starting at 2024-11-29 20:42:17
# ================================================
# Two-level compression: 46% 0.37% 0.0436918027% 0.0831530621% 0.00762512627%
# Partitioned to codelength 1.89888621 + 3.77728195 = 5.676168163 in 643 (642 non-trivial) modules.
# Super-level compression: 3.13313155% to codelength 5.498326347 in 240 top modules.
#
# Recursive sub-structure compression: 25.815896% 1.27942461% 0.0425083635% 0.0131252872% 0.00136718842% 0% . Found 7 levels with codelength 5.410354716
#
# => Trial 1/1 finished in 0.070892083s with codelength 5.41035472
#
#
# ================================================
# Summary after 1 trial
# ================================================
# Best end modular solution in 7 levels:
# Per level number of modules:         [        240,         569,         284,          51,           8,           2,           0] (sum: 1154)
# Per level number of leaf nodes:      [          0,         479,        2755,         713,         108,          19,           4] (sum: 4078)
# Per level average child degree:      [        240,     4.36667,     5.34095,     2.69014,     2.27451,       2.625,           2] (average: 15.4414)
# Per level codelength for modules:    [0.442693329, 1.603446426, 0.064960562, 0.002842061, 0.000761557, 0.000125219, 0.000000000] (sum: 2.114829153)
# Per level codelength for leaf nodes: [0.000000000, 0.042520116, 3.009619059, 0.225447971, 0.015164702, 0.002606904, 0.000166812] (sum: 3.295525563)
# Per level codelength total:          [0.442693329, 1.645966542, 3.074579621, 0.228290032, 0.015926259, 0.002732122, 0.000166812] (sum: 5.410354716)
#
# ===================================================
#   Infomap ends at 2024-11-29 20:42:17
#   (Elapsed time: 0.0775415s)
# ===================================================
# =======================================================
#   Infomap v2.8.0 starts at 2024-11-29 20:42:48
#   -> Input network:
#   -> No file output!
#   -> Configuration: directed
# =======================================================
#   -> Ordinary network input, using the Map Equation for first order network flows
# Calculating global network flow using flow model 'directed'...
#   -> Using unrecorded teleportation to links.
#   -> PageRank calculation done in 200 iterations.
#
#   => Sum node flow: 1, sum link flow: 1
# Build internal network with 4273 nodes and 8905 links...
#   -> One-level codelength: 10.5240213
#
# ================================================
# Trial 1/1 starting at 2024-11-29 20:42:48
# ================================================
# Two-level compression: 45% 0.55%
# Partitioned to codelength 1.93252195 + 3.84924264 = 5.781764591 in 673 modules.
# Super-level compression: 2.88971115% to codelength 5.614688295 in 256 top modules.
#
# Recursive sub-structure compression: 28.2756508% 1.09858484% 0.0168827115% 0.00121896844% 0% . Found 6 levels with codelength 5.521283599
#
# => Trial 1/1 finished in 0.0567555s with codelength 5.5212836
#
#
# ================================================
# Summary after 1 trial
# ================================================
# Best end modular solution in 6 levels:
# Per level number of modules:         [        256,         578,         311,          31,           2,           0] (sum: 1178)
# Per level number of leaf nodes:      [          0,         516,        2845,         850,          58,           4] (sum: 4273)
# Per level average child degree:      [        256,     4.27344,     5.46021,      2.8328,     1.93548,           2] (average: 16.5224)
# Per level codelength for modules:    [0.341514543, 1.724228517, 0.078867239, 0.000577201, 0.000113932, 0.000000000] (sum: 2.145301433)
# Per level codelength for leaf nodes: [0.000000000, 0.041159488, 3.063779404, 0.268064949, 0.002826550, 0.000151776] (sum: 3.375982166)
# Per level codelength total:          [0.341514543, 1.765388005, 3.142646643, 0.268642149, 0.002940482, 0.000151776] (sum: 5.521283599)
#
# ===================================================
#   Infomap ends at 2024-11-29 20:42:48
#   (Elapsed time: 0.0636775s)
# ===================================================
# =======================================================
#   Infomap v2.8.0 starts at 2024-11-29 20:43:21
#   -> Input network:
#   -> No file output!
#   -> Configuration: directed
# =======================================================
#   -> Ordinary network input, using the Map Equation for first order network flows
# Calculating global network flow using flow model 'directed'...
#   -> Using unrecorded teleportation to links.
#   -> PageRank calculation done in 200 iterations.
#
#   => Sum node flow: 1, sum link flow: 1
# Build internal network with 4504 nodes and 9566 links...
#   -> One-level codelength: 10.5956084
#
# ================================================
# Trial 1/1 starting at 2024-11-29 20:43:21
# ================================================
# Two-level compression: 44% 0.56% 0.0449678887% 0.0147401378%
# Partitioned to codelength 1.96331105 + 3.94768044 = 5.910991481 in 708 modules.
# Super-level compression: 3.0073612% to codelength 5.733226617 in 266 top modules.
#
# Recursive sub-structure compression: 23.3113142% 6.80171816% 0.0568709962% 0.00216189216% 0.00109119625% 0% . Found 7 levels with codelength 5.620092633
#
# => Trial 1/1 finished in 0.079813209s with codelength 5.62009263
#
#
# ================================================
# Summary after 1 trial
# ================================================
# Best end modular solution in 7 levels:
# Per level number of modules:         [        266,         501,         362,          80,           5,           2,           0] (sum: 1216)
# Per level number of leaf nodes:      [          0,         537,        2503,        1288,         166,           6,           4] (sum: 4504)
# Per level average child degree:      [        266,     3.90226,     5.71856,     3.77901,      2.1375,         1.6,           2] (average: 16.9137)
# Per level codelength for modules:    [0.374878952, 1.495469728, 0.351871892, 0.004638805, 0.000103815, 0.000103815, 0.000000000] (sum: 2.227067008)
# Per level codelength for leaf nodes: [0.000000000, 0.038575152, 2.609603316, 0.717322027, 0.027252353, 0.000134479, 0.000138298] (sum: 3.393025625)
# Per level codelength total:          [0.374878952, 1.534044880, 2.961475208, 0.721960833, 0.027356168, 0.000238294, 0.000138298] (sum: 5.620092633)
#
# ===================================================
#   Infomap ends at 2024-11-29 20:43:21
#   (Elapsed time: 0.087106375s)
# ===================================================
# =======================================================
#   Infomap v2.8.0 starts at 2024-11-29 20:44:02
#   -> Input network:
#   -> No file output!
#   -> Configuration: directed
# =======================================================
#   -> Ordinary network input, using the Map Equation for first order network flows
# Calculating global network flow using flow model 'directed'...
#   -> Using unrecorded teleportation to links.
#   -> PageRank calculation done in 200 iterations.
#
#   => Sum node flow: 1, sum link flow: 1
# Build internal network with 4842 nodes and 10524 links...
#   -> One-level codelength: 10.6797931
#
# ================================================
# Trial 1/1 starting at 2024-11-29 20:44:02
# ================================================
# Two-level compression: 43% 0.47% 0.0821875938% 0.0181581687% 0.0110943039%
# Partitioned to codelength 2.04069708 + 4.00009555 = 6.04079263 in 729 modules.
# Super-level compression: 2.89470521% to codelength 5.865929491 in 274 top modules.
#
# Recursive sub-structure compression: 27.1921465% 0.728661304% 0.0233423785% 0.00161000168% 0% . Found 6 levels with codelength 5.780681382
#
# => Trial 1/1 finished in 0.089937417s with codelength 5.78068138
#
#
# ================================================
# Summary after 1 trial
# ================================================
# Best end modular solution in 6 levels:
# Per level number of modules:         [        274,         644,         320,          36,           4,           0] (sum: 1278)
# Per level number of leaf nodes:      [          0,         564,        3374,         824,          74,           6] (sum: 4842)
# Per level average child degree:      [        274,     4.40876,     5.73602,      2.6875,     2.16667,         1.5] (average: 17.0065)
# Per level codelength for modules:    [0.359172743, 1.852880024, 0.073659641, 0.000970990, 0.000046436, 0.000000000] (sum: 2.286729834)
# Per level codelength for leaf nodes: [0.000000000, 0.035974276, 3.207215160, 0.244751383, 0.005741912, 0.000268816] (sum: 3.493951548)
# Per level codelength total:          [0.359172743, 1.888854301, 3.280874801, 0.245722373, 0.005788349, 0.000268816] (sum: 5.780681382)
#
# ===================================================
#   Infomap ends at 2024-11-29 20:44:02
#   (Elapsed time: 0.099283417s)
# ===================================================
# =======================================================
#   Infomap v2.8.0 starts at 2024-11-29 20:44:50
#   -> Input network:
#   -> No file output!
#   -> Configuration: directed
# =======================================================
#   -> Ordinary network input, using the Map Equation for first order network flows
# Calculating global network flow using flow model 'directed'...
#   -> Using unrecorded teleportation to links.
#   -> PageRank calculation done in 200 iterations.
#
#   => Sum node flow: 1, sum link flow: 1
# Build internal network with 5180 nodes and 11466 links...
#   -> One-level codelength: 10.7509349
#
# ================================================
# Trial 1/1 starting at 2024-11-29 20:44:50
# ================================================
# Two-level compression: 42% 0.46% 0.054066968% 0.00929004196%
# Partitioned to codelength 2.13216883 + 4.02035636 = 6.15252519 in 765 (763 non-trivial) modules.
# Super-level compression: 2.6566868% to codelength 5.989071866 in 271 top modules.
#
# Recursive sub-structure compression: 27.3034831% 0.359712304% 0.012676556% 0% . Found 5 levels with codelength 5.901596698
#
# => Trial 1/1 finished in 0.085607541s with codelength 5.9015967
#
#
# ================================================
# Summary after 1 trial
# ================================================
# Best end modular solution in 5 levels:
# Per level number of modules:         [        271,         720,         310,          28,           0] (sum: 1329)
# Per level number of leaf nodes:      [          0,         538,        3793,         779,          70] (sum: 5180)
# Per level average child degree:      [        271,     4.64207,     5.69861,     2.60323,         2.5] (average: 16.122)
# Per level codelength for modules:    [0.366441566, 1.989224641, 0.041444587, 0.000856611, 0.000000000] (sum: 2.397967405)
# Per level codelength for leaf nodes: [0.000000000, 0.034160236, 3.310366964, 0.152782925, 0.006319169] (sum: 3.503629293)
# Per level codelength total:          [0.366441566, 2.023384877, 3.351811550, 0.153639536, 0.006319169] (sum: 5.901596698)
#
# ===================================================
#   Infomap ends at 2024-11-29 20:44:50
#   (Elapsed time: 0.094442625s)
# ===================================================
# =======================================================
#   Infomap v2.8.0 starts at 2024-11-29 20:45:39
#   -> Input network:
#   -> No file output!
#   -> Configuration: directed
# =======================================================
#   -> Ordinary network input, using the Map Equation for first order network flows
# Calculating global network flow using flow model 'directed'...
#   -> Using unrecorded teleportation to links.
#   -> PageRank calculation done in 200 iterations.
#
#   => Sum node flow: 1, sum link flow: 1
# Build internal network with 5423 nodes and 12255 links...
#   -> One-level codelength: 10.8112257
#
# ================================================
# Trial 1/1 starting at 2024-11-29 20:45:39
# ================================================
# Two-level compression: 42% 0.45% 0.0371998069% 0.0150762849%
# Partitioned to codelength 2.20341048 + 4.02064396 = 6.224054438 in 794 (793 non-trivial) modules.
# Super-level compression: 2.88693009% to codelength 6.044370338 in 259 top modules.
#
# Recursive sub-structure compression: 24.4906831% 5.26260866% 0.0543197402% 0.00117690632% 0% . Found 6 levels with codelength 5.965729544
#
# => Trial 1/1 finished in 0.099231917s with codelength 5.96572954
#
#
# ================================================
# Summary after 1 trial
# ================================================
# Best end modular solution in 6 levels:
# Per level number of modules:         [        259,         609,         409,         101,           6,           0] (sum: 1384)
# Per level number of leaf nodes:      [          0,         533,        3291,        1361,         227,          11] (sum: 5423)
# Per level average child degree:      [        259,     4.40927,     6.07553,     3.57457,     2.30693,     1.83333] (average: 14.7465)
# Per level codelength for modules:    [0.365646142, 1.804055806, 0.264518684, 0.006096106, 0.000000000, 0.000000000] (sum: 2.440316738)
# Per level codelength for leaf nodes: [0.000000000, 0.033010475, 2.885723783, 0.576289201, 0.030153967, 0.000235379] (sum: 3.525412806)
# Per level codelength total:          [0.365646142, 1.837066281, 3.150242467, 0.582385308, 0.030153967, 0.000235379] (sum: 5.965729544)
#
# ===================================================
#   Infomap ends at 2024-11-29 20:45:39
#   (Elapsed time: 0.108278792s)
# ===================================================
# =======================================================
#   Infomap v2.8.0 starts at 2024-11-29 20:46:41
#   -> Input network:
#   -> No file output!
#   -> Configuration: directed
# =======================================================
#   -> Ordinary network input, using the Map Equation for first order network flows
# Calculating global network flow using flow model 'directed'...
#   -> Using unrecorded teleportation to links.
#   -> PageRank calculation done in 200 iterations.
#
#   => Sum node flow: 1, sum link flow: 1
# Build internal network with 5801 nodes and 13222 links...
#   -> One-level codelength: 10.8828882
#
# ================================================
# Trial 1/1 starting at 2024-11-29 20:46:41
# ================================================
# Two-level compression: 41% 0.57% 0.0371087484%
# Partitioned to codelength 2.27200113 + 4.05778393 = 6.329785053 in 841 (840 non-trivial) modules.
# Super-level compression: 2.71169161% to codelength 6.158140803 in 274 top modules.
#
# Recursive sub-structure compression: 23.9657439% 5.3664597% 0.0431063849% 0.000224908133% 0% . Found 6 levels with codelength 6.068068396
#
# => Trial 1/1 finished in 0.088695292s with codelength 6.0680684
#
#
# ================================================
# Summary after 1 trial
# ================================================
# Best end modular solution in 6 levels:
# Per level number of modules:         [        274,         620,         464,         116,           2,           0] (sum: 1476)
# Per level number of leaf nodes:      [          0,         562,        3329,        1663,         244,           3] (sum: 5801)
# Per level average child degree:      [        274,     4.31387,     6.11774,     3.83405,     2.12069,         1.5] (average: 15.216)
# Per level codelength for modules:    [0.403431512, 1.769545561, 0.311807740, 0.004742363, 0.000000000, 0.000000000] (sum: 2.489527177)
# Per level codelength for leaf nodes: [0.000000000, 0.029554383, 2.848040334, 0.684333521, 0.016576824, 0.000036158] (sum: 3.578541220)
# Per level codelength total:          [0.403431512, 1.799099944, 3.159848075, 0.689075884, 0.016576824, 0.000036158] (sum: 6.068068396)
#
# ===================================================
#   Infomap ends at 2024-11-29 20:46:41
#   (Elapsed time: 0.098383166s)
# ===================================================
# =======================================================
#   Infomap v2.8.0 starts at 2024-11-29 20:47:44
#   -> Input network:
#   -> No file output!
#   -> Configuration: directed
# =======================================================
#   -> Ordinary network input, using the Map Equation for first order network flows
# Calculating global network flow using flow model 'directed'...
#   -> Using unrecorded teleportation to links.
#   -> PageRank calculation done in 200 iterations.
#
#   => Sum node flow: 1, sum link flow: 1
# Build internal network with 6030 nodes and 14048 links...
#   -> One-level codelength: 10.9156079
#
# ================================================
# Trial 1/1 starting at 2024-11-29 20:47:44
# ================================================
# Two-level compression: 41% 0.38% 0.018992867% 0.00174053891% 0.00624180504%
# Partitioned to codelength 2.36207841 + 4.08371952 = 6.445797927 in 863 modules.
# Super-level compression: 2.59312937% to codelength 6.278650047 in 284 top modules.
#
# Recursive sub-structure compression: 22.9963632% 4.92044773% 0.0456673645% 0.000992775874% 0% . Found 6 levels with codelength 6.195254562
#
# => Trial 1/1 finished in 0.10691225s with codelength 6.19525456
#
#
# ================================================
# Summary after 1 trial
# ================================================
# Best end modular solution in 6 levels:
# Per level number of modules:         [        284,         663,         477,         132,           6,           0] (sum: 1562)
# Per level number of leaf nodes:      [          0,         580,        3574,        1598,         267,          11] (sum: 6030)
# Per level average child degree:      [        284,     4.37676,     6.11011,     3.62683,     2.06818,     1.83333] (average: 15.5042)
# Per level codelength for modules:    [0.437538594, 1.916653649, 0.287047398, 0.005926515, 0.000000000, 0.000000000] (sum: 2.647166156)
# Per level codelength for leaf nodes: [0.000000000, 0.030486316, 2.882521014, 0.614473580, 0.020270206, 0.000337289] (sum: 3.548088406)
# Per level codelength total:          [0.437538594, 1.947139965, 3.169568412, 0.620400095, 0.020270206, 0.000337289] (sum: 6.195254562)
#
# ===================================================
#   Infomap ends at 2024-11-29 20:47:44
#   (Elapsed time: 0.117192292s)
# ===================================================
# =======================================================
#   Infomap v2.8.0 starts at 2024-11-29 20:49:02
#   -> Input network:
#   -> No file output!
#   -> Configuration: directed
# =======================================================
#   -> Ordinary network input, using the Map Equation for first order network flows
# Calculating global network flow using flow model 'directed'...
#   -> Using unrecorded teleportation to links.
#   -> PageRank calculation done in 200 iterations.
#
#   => Sum node flow: 1, sum link flow: 1
# Build internal network with 6579 nodes and 15450 links...
#   -> One-level codelength: 10.9904259
#
# ================================================
# Trial 1/1 starting at 2024-11-29 20:49:02
# ================================================
# Two-level compression: 40% 0.48% 0.0196087364% 0.00202037036%
# Partitioned to codelength 2.36854566 + 4.20079966 = 6.569345315 in 918 (917 non-trivial) modules.
# Super-level compression: 2.19640368% to codelength 6.425055973 in 313 top modules.
#
# Recursive sub-structure compression: 26.6108571% 0.220803186% 0.0199395548% 0% . Found 5 levels with codelength 6.34931668
#
# => Trial 1/1 finished in 0.11466275s with codelength 6.34931668
#
#
# ================================================
# Summary after 1 trial
# ================================================
# Best end modular solution in 5 levels:
# Per level number of modules:         [        313,         870,         407,          47,           0] (sum: 1637)
# Per level number of leaf nodes:      [          0,         629,        4842,        1009,          99] (sum: 6579)
# Per level average child degree:      [        313,     4.78914,     6.03333,     2.59459,     2.10638] (average: 17.0114)
# Per level codelength for modules:    [0.385077341, 2.186065190, 0.054074600, 0.000494014, 0.000000000] (sum: 2.625711145)
# Per level codelength for leaf nodes: [0.000000000, 0.024945416, 3.528902060, 0.163106523, 0.006651536] (sum: 3.723605535)
# Per level codelength total:          [0.385077341, 2.211010606, 3.582976661, 0.163600537, 0.006651536] (sum: 6.349316680)
#
# ===================================================
#   Infomap ends at 2024-11-29 20:49:02
#   (Elapsed time: 0.131062334s)
# ===================================================
# =======================================================
#   Infomap v2.8.0 starts at 2024-11-29 20:50:22
#   -> Input network:
#   -> No file output!
#   -> Configuration: directed
# =======================================================
#   -> Ordinary network input, using the Map Equation for first order network flows
# Calculating global network flow using flow model 'directed'...
#   -> Using unrecorded teleportation to links.
#   -> PageRank calculation done in 200 iterations.
#
#   => Sum node flow: 1, sum link flow: 1
# Build internal network with 6872 nodes and 16365 links...
#   -> One-level codelength: 11.0666793
#
# ================================================
# Trial 1/1 starting at 2024-11-29 20:50:22
# ================================================
# Two-level compression: 39% 0.46% 0.133731949% 0.0646845649% 0.00687395872%
# Partitioned to codelength 2.47643004 + 4.2001887 = 6.676618736 in 948 (945 non-trivial) modules.
# Super-level compression: 1.97697036% to codelength 6.544623963 in 307 top modules.
#
# Recursive sub-structure compression: 25.2911377% 0.281373636% 0.0187463088% 0% . Found 5 levels with codelength 6.463393268
#
# => Trial 1/1 finished in 0.126595541s with codelength 6.46339327
#
#
# ================================================
# Summary after 1 trial
# ================================================
# Best end modular solution in 5 levels:
# Per level number of modules:         [        307,         926,         417,          56,           0] (sum: 1706)
# Per level number of leaf nodes:      [          0,         609,        5076,        1064,         123] (sum: 6872)
# Per level average child degree:      [        307,           5,     5.93197,     2.68585,     2.19643] (average: 16.0628)
# Per level codelength for modules:    [0.481841904, 2.239644807, 0.060371178, 0.000933250, 0.000000000] (sum: 2.782791139)
# Per level codelength for leaf nodes: [0.000000000, 0.023189642, 3.452661343, 0.196713399, 0.008037746] (sum: 3.680602129)
# Per level codelength total:          [0.481841904, 2.262834448, 3.513032520, 0.197646649, 0.008037746] (sum: 6.463393268)
#
# ===================================================
#   Infomap ends at 2024-11-29 20:50:22
#   (Elapsed time: 0.138393125s)
# ===================================================
# =======================================================
#   Infomap v2.8.0 starts at 2024-11-29 20:51:36
#   -> Input network:
#   -> No file output!
#   -> Configuration: directed
# =======================================================
#   -> Ordinary network input, using the Map Equation for first order network flows
# Calculating global network flow using flow model 'directed'...
#   -> Using unrecorded teleportation to links.
#   -> PageRank calculation done in 200 iterations.
#
#   => Sum node flow: 1, sum link flow: 1
# Build internal network with 7014 nodes and 16916 links...
#   -> One-level codelength: 11.0961463
#
# ================================================
# Trial 1/1 starting at 2024-11-29 20:51:36
# ================================================
# Two-level compression: 39% 0.51% 0.00496884905% 0.0175308558%
# Partitioned to codelength 2.48740239 + 4.27530607 = 6.762708453 in 963 (959 non-trivial) modules.
# Super-level compression: 2.06173425% to codelength 6.623279377 in 310 top modules.
#
# Recursive sub-structure compression: 26.0137026% 0.456240333% 0.019074825% 0.000154290968% 0% . Found 6 levels with codelength 6.54260324
#
# => Trial 1/1 finished in 0.1219395s with codelength 6.54260324
#
#
# ================================================
# Summary after 1 trial
# ================================================
# Best end modular solution in 6 levels:
# Per level number of modules:         [        310,         895,         449,          57,           4,           0] (sum: 1715)
# Per level number of leaf nodes:      [          0,         623,        5059,        1205,         119,           8] (sum: 7014)
# Per level average child degree:      [        310,     4.89677,     6.15419,     2.81069,     2.15789,           2] (average: 16.1827)
# Per level codelength for modules:    [0.396227243, 2.333533674, 0.099607215, 0.000740339, 0.000061600, 0.000000000] (sum: 2.830170071)
# Per level codelength for leaf nodes: [0.000000000, 0.022455046, 3.406612455, 0.274902787, 0.008183678, 0.000279203] (sum: 3.712433169)
# Per level codelength total:          [0.396227243, 2.355988720, 3.506219670, 0.275643127, 0.008245277, 0.000279203] (sum: 6.542603240)
#
# ===================================================
#   Infomap ends at 2024-11-29 20:51:36
#   (Elapsed time: 0.135438583s)
# ===================================================
#    Year  Community ID  Size  Number of Women  Percentage of Women  \
# 0  2002             1     3                0                  0.0
# 1  2002             2     2                0                  0.0
# 2  2002             3     2                0                  0.0
# 3  2002             4     2                0                  0.0
# 4  2002             5     2                0                  0.0
#
#                                           Members
# 0  Henri Cartan, Jean Dieudonné, Nicolas Bourbaki
# 1                 Paul Dirac, Carl David Anderson
# 2                 Brian Kernighan, Dennis Ritchie
# 3     Marquis de Condorcet, Jean-Charles de Borda
# 4           Vladimir Voevodsky, Laurent Lafforgue
#    Year  Community ID  Size  Number of Women  Percentage of Women  \
# 0  2004             1    94                2             2.127660
# 1  2004             2    77                1             1.298701
# 2  2005             1   462                3             0.649351
# 3  2005             2   308                8             2.597403
# 4  2006             1   624               13             2.083333
#
#                                              Members
# 0  Marie Curie, Henri Becquerel, Pierre Curie, Al...
# 1  Adam Sedgwick, Roderick Murchison, Charles Lap...
# 2  Charles Darwin, John Stevens Henslow, Charles ...
# 3  Marie Curie, Henri Becquerel, Pierre Curie, Li...
# 4  Joseph Priestley, Carl Wilhelm Scheele, John R...

# %%
all_communities_data = []

for year in range(2002, 2025):
    df_es_year = df_es[df_es['Year'] == year]

    G_es = gc.create_directed_graph(df_es_year, gender)

    node_mapping = {node: i for i, node in enumerate(G_es.nodes())}
    reverse_mapping = {i: node for node, i in node_mapping.items()}

    infomap = Infomap("--directed")

    for u, v, data in G_es.edges(data=True):
        weight = data.get('weight', 1)
        infomap.add_link(node_mapping[u], node_mapping[v], weight)

    infomap.run()

    community_summary = {}

    for node in infomap.tree:
        if node.is_leaf:
            original_node = reverse_mapping[node.node_id]
            community_id = node.module_id

            if community_id not in community_summary:
                community_summary[community_id] = {"members": [], "female_count": 0}

            community_summary[community_id]["members"].append(original_node)

            if original_node in G_es.nodes and "gender" in G_es.nodes[original_node]:
                gender_value = G_es.nodes[original_node]["gender"]

                if isinstance(gender_value, pd.Series):
                    if not gender_value.empty:
                        gender_value = gender_value.iloc[0]
                elif isinstance(gender_value, list):
                    gender_value = gender_value[0]

                if gender_value == "f":
                    community_summary[community_id]["female_count"] += 1

    community_data = []
    for community_id, data in community_summary.items():
        size = len(data["members"])
        female_count = data["female_count"]
        female_percentage = (female_count / size) * 100 if size > 0 else 0
        members_string = ", ".join(data["members"])

        community_data.append({
            "Year": year,
            "Community ID": community_id,
            "Size": size,
            "Number of Women": female_count,
            "Percentage of Women": female_percentage,
            "Members": members_string
        })

    all_communities_data.extend(community_data)

all_communities_df = pd.DataFrame(all_communities_data)

all_communities_df.to_csv("all_communities_infomap_es.csv", sep=";", index=False)
# Out:
# =======================================================
#   Infomap v2.8.0 starts at 2024-11-29 20:33:19
#   -> Input network:
#   -> No file output!
#   -> Configuration: directed
# =======================================================
#   -> Ordinary network input, using the Map Equation for first order network flows
# Calculating global network flow using flow model 'directed'...
#   -> Using unrecorded teleportation to links.
#   -> PageRank calculation done in 200 iterations.
#
#   => Sum node flow: 1, sum link flow: 1
# Build internal network with 6 nodes and 3 links...
#   -> One-level codelength: 1.5849625
#
# ================================================
# Trial 1/1 starting at 2024-11-29 20:33:19
# ================================================
# Two-level compression: 1e+02% 0%
# Partitioned to codelength 0 + 0 = 0 in 3 modules.
# Super-level compression: to codelength 0 in 3 top modules.
#
# Recursive sub-structure compression: nan% . Found 2 levels with codelength 0
#
# => Trial 1/1 finished in 8.4e-05s with codelength 0
#
#
# ================================================
# Summary after 1 trial
# ================================================
# Best end modular solution in 2 levels:
# Per level number of modules:         [          3,           0] (sum: 3)
# Per level number of leaf nodes:      [          0,           6] (sum: 6)
# Per level average child degree:      [          3,           2] (average: 2.33333)
# Per level codelength for modules:    [0.000000000, 0.000000000] (sum: 0.000000000)
# Per level codelength for leaf nodes: [0.000000000, 0.000000000] (sum: 0.000000000)
# Per level codelength total:          [0.000000000, 0.000000000] (sum: 0.000000000)
#
# ===================================================
#   Infomap ends at 2024-11-29 20:33:19
#   (Elapsed time: 0.00016s)
# ===================================================
# =======================================================
#   Infomap v2.8.0 starts at 2024-11-29 20:33:19
#   -> Input network:
#   -> No file output!
#   -> Configuration: directed
# =======================================================
#   -> Ordinary network input, using the Map Equation for first order network flows
# Calculating global network flow using flow model 'directed'...
#   -> Using unrecorded teleportation to links.
#   -> PageRank calculation done in 200 iterations.
#
#   => Sum node flow: 1, sum link flow: 1
# Build internal network with 68 nodes and 50 links...
#   -> One-level codelength: 4.56995437
#
# ================================================
# Trial 1/1 starting at 2024-11-29 20:33:19
# ================================================
# Two-level compression: 75% 3.8e-13%
# Partitioned to codelength 1.37390099e-15 + 1.12010386 = 1.120103855 in 27 modules.
# Super-level compression: to codelength 1.120103855 in 27 top modules.
#
# Recursive sub-structure compression: 2.26283363% 0% . Found 3 levels with codelength 1.094757768
#
# => Trial 1/1 finished in 0.000494542s with codelength 1.09475777
#
#
# ================================================
# Summary after 1 trial
# ================================================
# Best end modular solution in 3 levels:
# Per level number of modules:         [         27,           2,           0] (sum: 29)
# Per level number of leaf nodes:      [          0,          64,           4] (sum: 68)
# Per level average child degree:      [         27,     2.44444,           2] (average: 9.26117)
# Per level codelength for modules:    [0.000000000, 0.000000000, 0.000000000] (sum: 0.000000000)
# Per level codelength for leaf nodes: [0.000000000, 0.822245219, 0.272512550] (sum: 1.094757768)
# Per level codelength total:          [0.000000000, 0.822245219, 0.272512550] (sum: 1.094757768)
#
# ===================================================
#   Infomap ends at 2024-11-29 20:33:19
#   (Elapsed time: 0.000621833s)
# ===================================================
# =======================================================
#   Infomap v2.8.0 starts at 2024-11-29 20:33:20
#   -> Input network:
#   -> No file output!
#   -> Configuration: directed
# =======================================================
#   -> Ordinary network input, using the Map Equation for first order network flows
# Calculating global network flow using flow model 'directed'...
#   -> Using unrecorded teleportation to links.
#   -> PageRank calculation done in 200 iterations.
#
#   => Sum node flow: 1, sum link flow: 1
# Build internal network with 234 nodes and 192 links...
#   -> One-level codelength: 6.54565759
#
# ================================================
# Trial 1/1 starting at 2024-11-29 20:33:20
# ================================================
# Two-level compression: 78% 0% 0.175193811%
# Partitioned to codelength 0.0624670602 + 1.36319878 = 1.425665839 in 76 modules.
# Super-level compression: 3.5382138% to codelength 1.375222733 in 67 top modules.
#
# Recursive sub-structure compression: 14.7895264% 5.96718622% 1.1513463% 0% . Found 5 levels with codelength 1.285536539
#
# => Trial 1/1 finished in 0.00240775s with codelength 1.28553654
#
#
# ================================================
# Summary after 1 trial
# ================================================
# Best end modular solution in 5 levels:
# Per level number of modules:         [         67,          27,          11,           6,           0] (sum: 111)
# Per level number of leaf nodes:      [          0,         139,          63,          20,          12] (sum: 234)
# Per level average child degree:      [         67,     2.47761,     2.74074,     2.36364,           2] (average: 15.0393)
# Per level codelength for modules:    [0.000000000, 0.012023955, 0.025125879, 0.012023955, 0.000000000] (sum: 0.049173789)
# Per level codelength for leaf nodes: [0.000000000, 0.500934368, 0.516028715, 0.158410877, 0.060988789] (sum: 1.236362750)
# Per level codelength total:          [0.000000000, 0.512958323, 0.541154594, 0.170434832, 0.060988789] (sum: 1.285536539)
#
# ===================================================
#   Infomap ends at 2024-11-29 20:33:20
#   (Elapsed time: 0.002716959s)
# ===================================================
# =======================================================
#   Infomap v2.8.0 starts at 2024-11-29 20:33:22
#   -> Input network:
#   -> No file output!
#   -> Configuration: directed
# =======================================================
#   -> Ordinary network input, using the Map Equation for first order network flows
# Calculating global network flow using flow model 'directed'...
#   -> Using unrecorded teleportation to links.
#   -> PageRank calculation done in 200 iterations.
#
#   => Sum node flow: 1, sum link flow: 1
# Build internal network with 538 nodes and 553 links...
#   -> One-level codelength: 7.82662785
#
# ================================================
# Trial 1/1 starting at 2024-11-29 20:33:22
# ================================================
# Two-level compression: 67% 0.22%
# Partitioned to codelength 0.4648951 + 2.10673462 = 2.571629719 in 146 modules.
# Super-level compression: 5.99629941% 0.384011543% to codelength 2.408143902 in 97 top modules.
#
# Recursive sub-structure compression: 27.1811415% 22.3332166% 4.05721915% 4.15035897% 0.173857587% 0% . Found 7 levels with codelength 2.275083742
#
# => Trial 1/1 finished in 0.008023625s with codelength 2.27508374
#
#
# ================================================
# Summary after 1 trial
# ================================================
# Best end modular solution in 7 levels:
# Per level number of modules:         [         97,          43,          55,          33,          23,           8,           0] (sum: 259)
# Per level number of leaf nodes:      [          0,         190,          64,         143,          70,          56,          15] (sum: 538)
# Per level average child degree:      [         97,     2.40206,     2.76744,         3.2,     2.81818,     2.78261,       1.875] (average: 14.2152)
# Per level codelength for modules:    [0.000000000, 0.058056845, 0.257839988, 0.039579846, 0.074198878, 0.003542755, 0.000000000] (sum: 0.433218312)
# Per level codelength for leaf nodes: [0.000000000, 0.171666250, 0.113308931, 1.122343476, 0.187319395, 0.214622152, 0.032605227] (sum: 1.841865430)
# Per level codelength total:          [0.000000000, 0.229723095, 0.371148918, 1.161923322, 0.261518273, 0.218164906, 0.032605227] (sum: 2.275083742)
#
# ===================================================
#   Infomap ends at 2024-11-29 20:33:22
#   (Elapsed time: 0.008706917s)
# ===================================================
# =======================================================
#   Infomap v2.8.0 starts at 2024-11-29 20:33:26
#   -> Input network:
#   -> No file output!
#   -> Configuration: directed
# =======================================================
#   -> Ordinary network input, using the Map Equation for first order network flows
# Calculating global network flow using flow model 'directed'...
#   -> Using unrecorded teleportation to links.
#   -> PageRank calculation done in 200 iterations.
#
#   => Sum node flow: 1, sum link flow: 1
# Build internal network with 1042 nodes and 1203 links...
#   -> One-level codelength: 8.65483785
#
# ================================================
# Trial 1/1 starting at 2024-11-29 20:33:26
# ================================================
# Two-level compression: 65% 0.42% 0.11326551%
# Partitioned to codelength 0.592483074 + 2.38791209 = 2.98039516 in 263 (261 non-trivial) modules.
# Super-level compression: 6.37900324% 0.559353978% to codelength 2.774668138 in 154 top modules.
#
# Recursive sub-structure compression: 34.6528056% 24.6755352% 4.5313194% 0.213337171% 0.0377031716% 0.0193025987% 0% . Found 8 levels with codelength 2.667091132
#
# => Trial 1/1 finished in 0.016187875s with codelength 2.66709113
#
#
# ================================================
# Summary after 1 trial
# ================================================
# Best end modular solution in 8 levels:
# Per level number of modules:         [        154,          49,         128,          90,          20,           4,           2,           0] (sum: 447)
# Per level number of leaf nodes:      [          0,         336,          63,         355,         243,          35,           5,           5] (sum: 1042)
# Per level average child degree:      [        154,         2.5,     3.89796,     3.47656,     2.92222,        1.95,        1.75,         2.5] (average: 18.6967)
# Per level codelength for modules:    [0.000000000, 0.123736182, 0.360961591, 0.068458621, 0.014428232, 0.000639792, 0.000639792, 0.000000000] (sum: 0.568864209)
# Per level codelength for leaf nodes: [0.000000000, 0.187196904, 0.093662522, 1.366187566, 0.418650723, 0.030609832, 0.000000000, 0.001919375] (sum: 2.098226922)
# Per level codelength total:          [0.000000000, 0.310933087, 0.454624113, 1.434646187, 0.433078955, 0.031249624, 0.000639792, 0.001919375] (sum: 2.667091132)
#
# ===================================================
#   Infomap ends at 2024-11-29 20:33:26
#   (Elapsed time: 0.017581417s)
# ===================================================
# =======================================================
#   Infomap v2.8.0 starts at 2024-11-29 20:33:32
#   -> Input network:
#   -> No file output!
#   -> Configuration: directed
# =======================================================
#   -> Ordinary network input, using the Map Equation for first order network flows
# Calculating global network flow using flow model 'directed'...
#   -> Using unrecorded teleportation to links.
#   -> PageRank calculation done in 200 iterations.
#
#   => Sum node flow: 1, sum link flow: 1
# Build internal network with 1538 nodes and 2044 links...
#   -> One-level codelength: 9.1185417
#
# ================================================
# Trial 1/1 starting at 2024-11-29 20:33:32
# ================================================
# Two-level compression: 59% 0.33%
# Partitioned to codelength 0.881121847 + 2.81646506 = 3.697586911 in 331 (330 non-trivial) modules.
# Super-level compression: 4.83376244% to codelength 3.518854344 in 194 top modules.
#
# Recursive sub-structure compression: 24.7229521% 12.1672502% 0.645325937% 0.221578217% 0.0833069915% 0% . Found 7 levels with codelength 3.394851008
#
# => Trial 1/1 finished in 0.0196085s with codelength 3.39485101
#
#
# ================================================
# Summary after 1 trial
# ================================================
# Best end modular solution in 7 levels:
# Per level number of modules:         [        194,         176,         134,          45,          19,           9,           0] (sum: 577)
# Per level number of leaf nodes:      [          0,         397,         610,         386,          90,          33,          22] (sum: 1538)
# Per level average child degree:      [        194,     2.95361,     4.22727,     3.21642,     2.42222,     2.21053,     2.44444] (average: 20.9316)
# Per level codelength for modules:    [0.145753932, 0.545415258, 0.315557474, 0.013546548, 0.003163474, 0.002864825, 0.000000000] (sum: 1.026301512)
# Per level codelength for leaf nodes: [0.000000000, 0.132395486, 1.135075921, 1.001455995, 0.070757882, 0.012228211, 0.016636000] (sum: 2.368549496)
# Per level codelength total:          [0.145753932, 0.677810745, 1.450633396, 1.015002543, 0.073921356, 0.015093036, 0.016636000] (sum: 3.394851008)
#
# ===================================================
#   Infomap ends at 2024-11-29 20:33:32
#   (Elapsed time: 0.021626209s)
# ===================================================
# =======================================================
#   Infomap v2.8.0 starts at 2024-11-29 20:33:40
#   -> Input network:
#   -> No file output!
#   -> Configuration: directed
# =======================================================
#   -> Ordinary network input, using the Map Equation for first order network flows
# Calculating global network flow using flow model 'directed'...
#   -> Using unrecorded teleportation to links.
#   -> PageRank calculation done in 200 iterations.
#
#   => Sum node flow: 1, sum link flow: 1
# Build internal network with 2035 nodes and 2890 links...
#   -> One-level codelength: 9.5197878
#
# ================================================
# Trial 1/1 starting at 2024-11-29 20:33:40
# ================================================
# Two-level compression: 56% 0.2% 0.055260172%
# Partitioned to codelength 1.09405697 + 3.04114291 = 4.135199876 in 427 modules.
# Super-level compression: 4.74020546% to codelength 3.939182906 in 240 top modules.
#
# Recursive sub-structure compression: 30.8039847% 1.78307255% 0.204640136% 0.0198930418% 0.00242671476% 0% . Found 7 levels with codelength 3.841147762
#
# => Trial 1/1 finished in 0.025741292s with codelength 3.84114776
#
#
# ================================================
# Summary after 1 trial
# ================================================
# Best end modular solution in 7 levels:
# Per level number of modules:         [        240,         286,         183,          37,           6,           2,           0] (sum: 754)
# Per level number of leaf nodes:      [          0,         486,        1035,         416,          85,          10,           3] (sum: 2035)
# Per level average child degree:      [        240,     3.21667,     4.25874,     2.47541,     2.45946,           2,         1.5] (average: 23.8953)
# Per level codelength for modules:    [0.183649276, 0.942845050, 0.078957782, 0.008607783, 0.000000000, 0.000246966, 0.000000000] (sum: 1.214306858)
# Per level codelength for leaf nodes: [0.000000000, 0.132516345, 2.122193339, 0.329685433, 0.036956919, 0.005488869, 0.000000000] (sum: 2.626840904)
# Per level codelength total:          [0.183649276, 1.075361395, 2.201151121, 0.338293216, 0.036956919, 0.005735835, 0.000000000] (sum: 3.841147762)
#
# ===================================================
#   Infomap ends at 2024-11-29 20:33:40
#   (Elapsed time: 0.028532834s)
# ===================================================
# =======================================================
#   Infomap v2.8.0 starts at 2024-11-29 20:33:49
#   -> Input network:
#   -> No file output!
#   -> Configuration: directed
# =======================================================
#   -> Ordinary network input, using the Map Equation for first order network flows
# Calculating global network flow using flow model 'directed'...
#   -> Using unrecorded teleportation to links.
#   -> PageRank calculation done in 200 iterations.
#
#   => Sum node flow: 1, sum link flow: 1
# Build internal network with 2311 nodes and 3411 links...
#   -> One-level codelength: 9.70831152
#
# ================================================
# Trial 1/1 starting at 2024-11-29 20:33:49
# ================================================
# Two-level compression: 54% 0.38% 0.0808484629% 0.0111120059%
# Partitioned to codelength 1.19556067 + 3.25605466 = 4.451615327 in 458 modules.
# Super-level compression: 3.51528594% to codelength 4.295128319 in 251 top modules.
#
# Recursive sub-structure compression: 28.2389743% 7.98230043% 0.445787968% 0.0287784487% 0.0026756626% 0% . Found 7 levels with codelength 4.180863011
#
# => Trial 1/1 finished in 0.038232792s with codelength 4.18086301
#
#
# ================================================
# Summary after 1 trial
# ================================================
# Best end modular solution in 7 levels:
# Per level number of modules:         [        251,         240,         242,          81,          10,           2,           0] (sum: 826)
# Per level number of leaf nodes:      [          0,         535,         877,         684,         189,          23,           3] (sum: 2311)
# Per level average child degree:      [        251,     3.08765,      4.6625,     3.16116,     2.45679,         2.5,         1.5] (average: 23.4573)
# Per level codelength for modules:    [0.172611157, 0.915710292, 0.250977768, 0.014541222, 0.001048822, 0.000000000, 0.000000000] (sum: 1.354889262)
# Per level codelength for leaf nodes: [0.000000000, 0.136704081, 1.749603771, 0.834517820, 0.096257330, 0.008681900, 0.000208847] (sum: 2.825973749)
# Per level codelength total:          [0.172611157, 1.052414373, 2.000581539, 0.849059042, 0.097306152, 0.008681900, 0.000208847] (sum: 4.180863011)
#
# ===================================================
#   Infomap ends at 2024-11-29 20:33:49
#   (Elapsed time: 0.041537417s)
# ===================================================
# =======================================================
#   Infomap v2.8.0 starts at 2024-11-29 20:34:00
#   -> Input network:
#   -> No file output!
#   -> Configuration: directed
# =======================================================
#   -> Ordinary network input, using the Map Equation for first order network flows
# Calculating global network flow using flow model 'directed'...
#   -> Using unrecorded teleportation to links.
#   -> PageRank calculation done in 200 iterations.
#
#   => Sum node flow: 1, sum link flow: 1
# Build internal network with 2634 nodes and 3993 links...
#   -> One-level codelength: 9.86911048
#
# ================================================
# Trial 1/1 starting at 2024-11-29 20:34:00
# ================================================
# Two-level compression: 52% 0.65% 0.0306522139% 0.00900284461% 0.0104784293%
# Partitioned to codelength 1.41131796 + 3.28101738 = 4.692335338 in 514 modules.
# Super-level compression: 3.42789034% to codelength 4.531487229 in 274 top modules.
#
# Recursive sub-structure compression: 31.2237292% 1.67465103% 0.533138197% 0.0102478954% 0.00207838763% 0% . Found 7 levels with codelength 4.450008516
#
# => Trial 1/1 finished in 0.042187167s with codelength 4.45000852
#
#
# ================================================
# Summary after 1 trial
# ================================================
# Best end modular solution in 7 levels:
# Per level number of modules:         [        274,         324,         222,          58,           4,           2,           0] (sum: 884)
# Per level number of leaf nodes:      [          0,         575,        1356,         534,         158,           8,           3] (sum: 2634)
# Per level average child degree:      [        274,     3.28102,     4.87037,     2.66667,      2.7931,         2.5,         1.5] (average: 24.9493)
# Per level codelength for modules:    [0.218099659, 1.242213884, 0.071914396, 0.011090274, 0.000348647, 0.000000000, 0.000000000] (sum: 1.543666861)
# Per level codelength for leaf nodes: [0.000000000, 0.117096201, 2.423188506, 0.295985924, 0.067879904, 0.002018451, 0.000172670] (sum: 2.906341655)
# Per level codelength total:          [0.218099659, 1.359310085, 2.495102902, 0.307076199, 0.068228551, 0.002018451, 0.000172670] (sum: 4.450008516)
#
# ===================================================
#   Infomap ends at 2024-11-29 20:34:00
#   (Elapsed time: 0.045929334s)
# ===================================================
# =======================================================
#   Infomap v2.8.0 starts at 2024-11-29 20:34:12
#   -> Input network:
#   -> No file output!
#   -> Configuration: directed
# =======================================================
#   -> Ordinary network input, using the Map Equation for first order network flows
# Calculating global network flow using flow model 'directed'...
#   -> Using unrecorded teleportation to links.
#   -> PageRank calculation done in 200 iterations.
#
#   => Sum node flow: 1, sum link flow: 1
# Build internal network with 2876 nodes and 4541 links...
#   -> One-level codelength: 9.97561784
#
# ================================================
# Trial 1/1 starting at 2024-11-29 20:34:12
# ================================================
# Two-level compression: 52% 0.23% 0.0798855606% 0.0146115627% 0.0186964045%
# Partitioned to codelength 1.36796523 + 3.37819773 = 4.746162952 in 545 modules.
# Super-level compression: 3.96020021% to codelength 4.558205397 in 267 top modules.
#
# Recursive sub-structure compression: 24.6890005% 9.4182004% 0.497925644% 0.0548924551% 0.00160367185% 0% . Found 7 levels with codelength 4.457744719
#
# => Trial 1/1 finished in 0.050113458s with codelength 4.45774472
#
#
# ================================================
# Summary after 1 trial
# ================================================
# Best end modular solution in 7 levels:
# Per level number of modules:         [        267,         329,         287,          91,          19,           2,           0] (sum: 995)
# Per level number of leaf nodes:      [          0,         549,        1188,         896,         196,          44,           3] (sum: 2876)
# Per level average child degree:      [        267,     3.28839,     4.48328,     3.43902,     2.36264,     2.42105,         1.5] (average: 21.9083)
# Per level codelength for modules:    [0.241199059, 0.941903323, 0.373863713, 0.024331821, 0.001047173, 0.000000000, 0.000000000] (sum: 1.582345088)
# Per level codelength for leaf nodes: [0.000000000, 0.090467892, 1.778120775, 0.886487758, 0.105847659, 0.014330251, 0.000145296] (sum: 2.875399631)
# Per level codelength total:          [0.241199059, 1.032371214, 2.151984488, 0.910819579, 0.106894832, 0.014330251, 0.000145296] (sum: 4.457744719)
#
# ===================================================
#   Infomap ends at 2024-11-29 20:34:12
#   (Elapsed time: 0.054430958s)
# ===================================================
# =======================================================
#   Infomap v2.8.0 starts at 2024-11-29 20:34:26
#   -> Input network:
#   -> No file output!
#   -> Configuration: directed
# =======================================================
#   -> Ordinary network input, using the Map Equation for first order network flows
# Calculating global network flow using flow model 'directed'...
#   -> Using unrecorded teleportation to links.
#   -> PageRank calculation done in 200 iterations.
#
#   => Sum node flow: 1, sum link flow: 1
# Build internal network with 3078 nodes and 4927 links...
#   -> One-level codelength: 10.0314201
#
# ================================================
# Trial 1/1 starting at 2024-11-29 20:34:26
# ================================================
# Two-level compression: 51% 0.3% 0.0587213299% 0.00891229759% 0.00773124894%
# Partitioned to codelength 1.45274859 + 3.40795677 = 4.860705362 in 576 (574 non-trivial) modules.
# Super-level compression: 4.09782305% to codelength 4.661522257 in 281 top modules.
#
# Recursive sub-structure compression: 29.6531127% 1.20879515% 0.377582009% 0.00992731025% 0.00140938698% 0% . Found 7 levels with codelength 4.569172251
#
# => Trial 1/1 finished in 0.048740167s with codelength 4.56917225
#
#
# ================================================
# Summary after 1 trial
# ================================================
# Best end modular solution in 7 levels:
# Per level number of modules:         [        281,         432,         240,          61,           6,           2,           0] (sum: 1022)
# Per level number of leaf nodes:      [          0,         580,        1794,         540,         151,          10,           3] (sum: 3078)
# Per level average child degree:      [        281,     3.60142,     4.70833,     2.50417,     2.57377,           2,         1.5] (average: 22.9561)
# Per level codelength for modules:    [0.269571451, 1.250000880, 0.071872875, 0.012027313, 0.000497683, 0.000000000, 0.000000000] (sum: 1.603970201)
# Per level codelength for leaf nodes: [0.000000000, 0.075706834, 2.536790822, 0.284371774, 0.067283523, 0.000918212, 0.000130885] (sum: 2.965202049)
# Per level codelength total:          [0.269571451, 1.325707714, 2.608663697, 0.296399087, 0.067781206, 0.000918212, 0.000130885] (sum: 4.569172251)
#
# ===================================================
#   Infomap ends at 2024-11-29 20:34:26
#   (Elapsed time: 0.053399791s)
# ===================================================
# =======================================================
#   Infomap v2.8.0 starts at 2024-11-29 20:34:40
#   -> Input network:
#   -> No file output!
#   -> Configuration: directed
# =======================================================
#   -> Ordinary network input, using the Map Equation for first order network flows
# Calculating global network flow using flow model 'directed'...
#   -> Using unrecorded teleportation to links.
#   -> PageRank calculation done in 200 iterations.
#
#   => Sum node flow: 1, sum link flow: 1
# Build internal network with 3248 nodes and 5250 links...
#   -> One-level codelength: 10.1245502
#
# ================================================
# Trial 1/1 starting at 2024-11-29 20:34:40
# ================================================
# Two-level compression: 51% 0.42%
# Partitioned to codelength 1.52558408 + 3.44516851 = 4.970752583 in 601 (600 non-trivial) modules.
# Super-level compression: 3.89805058% to codelength 4.776990133 in 292 top modules.
#
# Recursive sub-structure compression: 29.414301% 1.3054013% 0.166967306% 0.0063461907% 0% . Found 6 levels with codelength 4.689643188
#
# => Trial 1/1 finished in 0.040669167s with codelength 4.68964319
#
#
# ================================================
# Summary after 1 trial
# ================================================
# Best end modular solution in 6 levels:
# Per level number of modules:         [        292,         462,         245,          52,           7,           0] (sum: 1058)
# Per level number of leaf nodes:      [          0,         584,        1968,         567,         118,          11] (sum: 3248)
# Per level average child degree:      [        292,     3.58219,     4.79004,     2.52653,     2.40385,     1.57143] (average: 23.5701)
# Per level codelength for modules:    [0.304623749, 1.242115134, 0.067849992, 0.005545006, 0.001126385, 0.000000000] (sum: 1.621260266)
# Per level codelength for leaf nodes: [0.000000000, 0.069626532, 2.686887905, 0.279778972, 0.030976947, 0.001112566] (sum: 3.068382922)
# Per level codelength total:          [0.304623749, 1.311741666, 2.754737897, 0.285323979, 0.032103332, 0.001112566] (sum: 4.689643188)
#
# ===================================================
#   Infomap ends at 2024-11-29 20:34:40
#   (Elapsed time: 0.045495083s)
# ===================================================
# =======================================================
#   Infomap v2.8.0 starts at 2024-11-29 20:34:55
#   -> Input network:
#   -> No file output!
#   -> Configuration: directed
# =======================================================
#   -> Ordinary network input, using the Map Equation for first order network flows
# Calculating global network flow using flow model 'directed'...
#   -> Using unrecorded teleportation to links.
#   -> PageRank calculation done in 200 iterations.
#
#   => Sum node flow: 1, sum link flow: 1
# Build internal network with 3380 nodes and 5680 links...
#   -> One-level codelength: 10.1793505
#
# ================================================
# Trial 1/1 starting at 2024-11-29 20:34:55
# ================================================
# Two-level compression: 51% 0.28% 0.00558491665%
# Partitioned to codelength 1.52035561 + 3.50334657 = 5.023702188 in 602 (600 non-trivial) modules.
# Super-level compression: 3.67879998% to codelength 4.838890232 in 287 top modules.
#
# Recursive sub-structure compression: 30.1426758% 1.24615524% 0.0753037817% 0.0048086752% 0% . Found 6 levels with codelength 4.749516388
#
# => Trial 1/1 finished in 0.046148917s with codelength 4.74951639
#
#
# ================================================
# Summary after 1 trial
# ================================================
# Best end modular solution in 6 levels:
# Per level number of modules:         [        287,         456,         271,          61,           6,           0] (sum: 1081)
# Per level number of leaf nodes:      [          0,         593,        1988,         653,         136,          10] (sum: 3380)
# Per level average child degree:      [        287,     3.65505,     4.95395,     2.63469,     2.32787,     1.66667] (average: 22.3319)
# Per level codelength for modules:    [0.301183053, 1.288982112, 0.069740609, 0.007946613, 0.000265911, 0.000000000] (sum: 1.668118297)
# Per level codelength for leaf nodes: [0.000000000, 0.084701334, 2.663167453, 0.300136324, 0.032571921, 0.000821058] (sum: 3.081398090)
# Per level codelength total:          [0.301183053, 1.373683445, 2.732908062, 0.308082937, 0.032837832, 0.000821058] (sum: 4.749516388)
#
# ===================================================
#   Infomap ends at 2024-11-29 20:34:55
#   (Elapsed time: 0.051295791s)
# ===================================================
# =======================================================
#   Infomap v2.8.0 starts at 2024-11-29 20:35:11
#   -> Input network:
#   -> No file output!
#   -> Configuration: directed
# =======================================================
#   -> Ordinary network input, using the Map Equation for first order network flows
# Calculating global network flow using flow model 'directed'...
#   -> Using unrecorded teleportation to links.
#   -> PageRank calculation done in 200 iterations.
#
#   => Sum node flow: 1, sum link flow: 1
# Build internal network with 3522 nodes and 5967 links...
#   -> One-level codelength: 10.2900532
#
# ================================================
# Trial 1/1 starting at 2024-11-29 20:35:11
# ================================================
# Two-level compression: 50% 0.31% 0.0905146352% 0.00497783299%
# Partitioned to codelength 1.58088755 + 3.55646326 = 5.13735081 in 628 (624 non-trivial) modules.
# Super-level compression: 3.45138842% to codelength 4.960040879 in 302 top modules.
#
# Recursive sub-structure compression: 30.2143037% 0.894990109% 0.06965952% 0.00698766872% 0% . Found 6 levels with codelength 4.880576896
#
# => Trial 1/1 finished in 0.054046625s with codelength 4.8805769
#
#
# ================================================
# Summary after 1 trial
# ================================================
# Best end modular solution in 6 levels:
# Per level number of modules:         [        302,         473,         281,          50,           8,           0] (sum: 1114)
# Per level number of leaf nodes:      [          0,         608,        2070,         716,         112,          16] (sum: 3522)
# Per level average child degree:      [        302,     3.57947,      4.9704,     2.72598,         2.4,           2] (average: 23.5477)
# Per level codelength for modules:    [0.280764319, 1.367340639, 0.078364730, 0.003581298, 0.000419802, 0.000000000] (sum: 1.730470787)
# Per level codelength for leaf nodes: [0.000000000, 0.056453574, 2.741999759, 0.320293614, 0.029226878, 0.002132284] (sum: 3.150106109)
# Per level codelength total:          [0.280764319, 1.423794212, 2.820364489, 0.323874912, 0.029646681, 0.002132284] (sum: 4.880576896)
#
# ===================================================
#   Infomap ends at 2024-11-29 20:35:11
#   (Elapsed time: 0.059342042s)
# ===================================================
# =======================================================
#   Infomap v2.8.0 starts at 2024-11-29 20:35:30
#   -> Input network:
#   -> No file output!
#   -> Configuration: directed
# =======================================================
#   -> Ordinary network input, using the Map Equation for first order network flows
# Calculating global network flow using flow model 'directed'...
#   -> Using unrecorded teleportation to links.
#   -> PageRank calculation done in 200 iterations.
#
#   => Sum node flow: 1, sum link flow: 1
# Build internal network with 3739 nodes and 6515 links...
#   -> One-level codelength: 10.3253525
#
# ================================================
# Trial 1/1 starting at 2024-11-29 20:35:30
# ================================================
# Two-level compression: 49% 0.21% 0.00773766785% 0.00221673844%
# Partitioned to codelength 1.64170177 + 3.6215502 = 5.263251963 in 640 (636 non-trivial) modules.
# Super-level compression: 3.10004435% to codelength 5.100088818 in 298 top modules.
#
# Recursive sub-structure compression: 29.063711% 0.829580563% 0.056612548% 0.00404709649% 0% . Found 6 levels with codelength 5.00838786
#
# => Trial 1/1 finished in 0.056859375s with codelength 5.00838786
#
#
# ================================================
# Summary after 1 trial
# ================================================
# Best end modular solution in 6 levels:
# Per level number of modules:         [        298,         528,         239,          45,           6,           0] (sum: 1116)
# Per level number of leaf nodes:      [          0,         604,        2426,         604,          93,          12] (sum: 3739)
# Per level average child degree:      [        298,     3.79866,     5.04735,     2.71548,         2.2,           2] (average: 22.3603)
# Per level codelength for modules:    [0.364896074, 1.413932475, 0.049629438, 0.002333332, 0.000146815, 0.000000000] (sum: 1.830938134)
# Per level codelength for leaf nodes: [0.000000000, 0.048657276, 2.860315653, 0.246372569, 0.020713397, 0.001390833] (sum: 3.177449727)
# Per level codelength total:          [0.364896074, 1.462589751, 2.909945091, 0.248705900, 0.020860211, 0.001390833] (sum: 5.008387860)
#
# ===================================================
#   Infomap ends at 2024-11-29 20:35:30
#   (Elapsed time: 0.062766084s)
# ===================================================
# =======================================================
#   Infomap v2.8.0 starts at 2024-11-29 20:35:55
#   -> Input network:
#   -> No file output!
#   -> Configuration: directed
# =======================================================
#   -> Ordinary network input, using the Map Equation for first order network flows
# Calculating global network flow using flow model 'directed'...
#   -> Using unrecorded teleportation to links.
#   -> PageRank calculation done in 200 iterations.
#
#   => Sum node flow: 1, sum link flow: 1
# Build internal network with 4015 nodes and 7044 links...
#   -> One-level codelength: 10.3547377
#
# ================================================
# Trial 1/1 starting at 2024-11-29 20:35:55
# ================================================
# Two-level compression: 48% 0.38%
# Partitioned to codelength 1.69832775 + 3.64950126 = 5.347829008 in 687 (685 non-trivial) modules.
# Super-level compression: 3.01609564% to codelength 5.186533371 in 324 top modules.
#
# Recursive sub-structure compression: 29.8561168% 0.633474752% 0.0533747444% 0.00496464626% 0% . Found 6 levels with codelength 5.100986661
#
# => Trial 1/1 finished in 0.068948667s with codelength 5.10098666
#
#
# ================================================
# Summary after 1 trial
# ================================================
# Best end modular solution in 6 levels:
# Per level number of modules:         [        324,         546,         268,          44,           6,           0] (sum: 1188)
# Per level number of leaf nodes:      [          0,         663,        2523,         727,          86,          16] (sum: 4015)
# Per level average child degree:      [        324,     3.73148,     5.11172,     2.87687,     2.09091,     2.66667] (average: 24.2566)
# Per level codelength for modules:    [0.325271969, 1.474574588, 0.078008671, 0.001909704, 0.000507140, 0.000000000] (sum: 1.880272072)
# Per level codelength for leaf nodes: [0.000000000, 0.044369513, 2.818881540, 0.344885157, 0.010230345, 0.002348035] (sum: 3.220714589)
# Per level codelength total:          [0.325271969, 1.518944101, 2.896890211, 0.346794860, 0.010737485, 0.002348035] (sum: 5.100986661)
#
# ===================================================
#   Infomap ends at 2024-11-29 20:35:55
#   (Elapsed time: 0.078236916s)
# ===================================================
# =======================================================
#   Infomap v2.8.0 starts at 2024-11-29 20:36:19
#   -> Input network:
#   -> No file output!
#   -> Configuration: directed
# =======================================================
#   -> Ordinary network input, using the Map Equation for first order network flows
# Calculating global network flow using flow model 'directed'...
#   -> Using unrecorded teleportation to links.
#   -> PageRank calculation done in 200 iterations.
#
#   => Sum node flow: 1, sum link flow: 1
# Build internal network with 4214 nodes and 7467 links...
#   -> One-level codelength: 10.3914066
#
# ================================================
# Trial 1/1 starting at 2024-11-29 20:36:19
# ================================================
# Two-level compression: 47% 0.43% 0.046158881% 0.0137314604%
# Partitioned to codelength 1.81109258 + 3.63300031 = 5.44409289 in 722 (721 non-trivial) modules.
# Super-level compression: 3.37523953% to codelength 5.260341715 in 336 top modules.
#
# Recursive sub-structure compression: 30.1217516% 0.585201622% 0.11358457% 0.0177452822% 0.0015666511% 0% . Found 7 levels with codelength 5.174486468
#
# => Trial 1/1 finished in 0.068524292s with codelength 5.17448647
#
#
# ================================================
# Summary after 1 trial
# ================================================
# Best end modular solution in 7 levels:
# Per level number of modules:         [        336,         579,         284,          48,          23,           4,           0] (sum: 1274)
# Per level number of leaf nodes:      [          0,         679,        2691,         697,          98,          42,           7] (sum: 4214)
# Per level average child degree:      [        336,     3.74405,     5.13817,     2.62324,     2.52083,           2,        1.75] (average: 24.6457)
# Per level codelength for modules:    [0.324961092, 1.537114353, 0.061503216, 0.002665566, 0.001115578, 0.000000000, 0.000000000] (sum: 1.927359805)
# Per level codelength for leaf nodes: [0.000000000, 0.041537809, 2.872770707, 0.313862526, 0.014564020, 0.004229467, 0.000162135] (sum: 3.247126663)
# Per level codelength total:          [0.324961092, 1.578652162, 2.934273922, 0.316528092, 0.015679598, 0.004229467, 0.000162135] (sum: 5.174486468)
#
# ===================================================
#   Infomap ends at 2024-11-29 20:36:19
#   (Elapsed time: 0.07534225s)
# ===================================================
# =======================================================
#   Infomap v2.8.0 starts at 2024-11-29 20:36:47
#   -> Input network:
#   -> No file output!
#   -> Configuration: directed
# =======================================================
#   -> Ordinary network input, using the Map Equation for first order network flows
# Calculating global network flow using flow model 'directed'...
#   -> Using unrecorded teleportation to links.
#   -> PageRank calculation done in 200 iterations.
#
#   => Sum node flow: 1, sum link flow: 1
# Build internal network with 4527 nodes and 8089 links...
#   -> One-level codelength: 10.4434296
#
# ================================================
# Trial 1/1 starting at 2024-11-29 20:36:47
# ================================================
# Two-level compression: 47% 0.36% 0.0722740141% 0.00738018199%
# Partitioned to codelength 1.83899981 + 3.66794518 = 5.506944991 in 753 (749 non-trivial) modules.
# Super-level compression: 3.36973837% to codelength 5.321375353 in 350 top modules.
#
# Recursive sub-structure compression: 29.842353% 0.838750455% 0.0743598547% 0.00459254977% 0% . Found 6 levels with codelength 5.232771525
#
# => Trial 1/1 finished in 0.079662417s with codelength 5.23277152
#
#
# ================================================
# Summary after 1 trial
# ================================================
# Best end modular solution in 6 levels:
# Per level number of modules:         [        350,         618,         321,          46,           8,           0] (sum: 1343)
# Per level number of leaf nodes:      [          0,         687,        2886,         831,         106,          17] (sum: 4527)
# Per level average child degree:      [        350,     3.72857,     5.18932,     2.73209,     2.47826,       2.125] (average: 24.9953)
# Per level codelength for modules:    [0.300039852, 1.634718252, 0.059270804, 0.003307356, 0.000253155, 0.000000000] (sum: 1.997589420)
# Per level codelength for leaf nodes: [0.000000000, 0.043217943, 2.897356989, 0.277550328, 0.015646066, 0.001410779] (sum: 3.235182105)
# Per level codelength total:          [0.300039852, 1.677936195, 2.956627794, 0.280857684, 0.015899221, 0.001410779] (sum: 5.232771525)
#
# ===================================================
#   Infomap ends at 2024-11-29 20:36:47
#   (Elapsed time: 0.087194667s)
# ===================================================
# =======================================================
#   Infomap v2.8.0 starts at 2024-11-29 20:37:18
#   -> Input network:
#   -> No file output!
#   -> Configuration: directed
# =======================================================
#   -> Ordinary network input, using the Map Equation for first order network flows
# Calculating global network flow using flow model 'directed'...
#   -> Using unrecorded teleportation to links.
#   -> PageRank calculation done in 200 iterations.
#
#   => Sum node flow: 1, sum link flow: 1
# Build internal network with 4726 nodes and 8484 links...
#   -> One-level codelength: 10.4737595
#
# ================================================
# Trial 1/1 starting at 2024-11-29 20:37:18
# ================================================
# Two-level compression: 47% 0.28% 0.0931714993% 0.0544130439% 0.00441284775% 0.00294872406%
# Partitioned to codelength 1.84535403 + 3.68955931 = 5.534913343 in 802 (798 non-trivial) modules.
# Super-level compression: 3.20210068% to codelength 5.357679845 in 367 top modules.
#
# Recursive sub-structure compression: 28.8454866% 0.616556919% 0.0700739148% 0.00298966394% 0% . Found 6 levels with codelength 5.256316145
#
# => Trial 1/1 finished in 0.119180041s with codelength 5.25631614
#
#
# ================================================
# Summary after 1 trial
# ================================================
# Best end modular solution in 6 levels:
# Per level number of modules:         [        367,         660,         295,          46,           6,           0] (sum: 1374)
# Per level number of leaf nodes:      [          0,         731,        3122,         761,         101,          11] (sum: 4726)
# Per level average child degree:      [        367,     3.79019,     5.17727,     2.73559,     2.32609,     1.83333] (average: 26.2506)
# Per level codelength for modules:    [0.343115311, 1.627993449, 0.049020907, 0.003356627, 0.000131099, 0.000000000] (sum: 2.023617394)
# Per level codelength for leaf nodes: [0.000000000, 0.037951273, 2.945581535, 0.233690572, 0.015021676, 0.000453694] (sum: 3.232698751)
# Per level codelength total:          [0.343115311, 1.665944723, 2.994602442, 0.237047200, 0.015152776, 0.000453694] (sum: 5.256316145)
#
# ===================================================
#   Infomap ends at 2024-11-29 20:37:19
#   (Elapsed time: 0.128215792s)
# ===================================================
# =======================================================
#   Infomap v2.8.0 starts at 2024-11-29 20:37:47
#   -> Input network:
#   -> No file output!
#   -> Configuration: directed
# =======================================================
#   -> Ordinary network input, using the Map Equation for first order network flows
# Calculating global network flow using flow model 'directed'...
#   -> Using unrecorded teleportation to links.
#   -> PageRank calculation done in 200 iterations.
#
#   => Sum node flow: 1, sum link flow: 1
# Build internal network with 4935 nodes and 8884 links...
#   -> One-level codelength: 10.4875661
#
# ================================================
# Trial 1/1 starting at 2024-11-29 20:37:47
# ================================================
# Two-level compression: 47% 0.48% 0.0517835194%
# Partitioned to codelength 1.87854874 + 3.6598282 = 5.538376935 in 828 (825 non-trivial) modules.
# Super-level compression: 3.25586012% to codelength 5.358055129 in 383 top modules.
#
# Recursive sub-structure compression: 28.5098487% 0.77699204% 0.0266440991% 0.00155731951% 0% . Found 6 levels with codelength 5.27724932
#
# => Trial 1/1 finished in 0.075882291s with codelength 5.27724932
#
#
# ================================================
# Summary after 1 trial
# ================================================
# Best end modular solution in 6 levels:
# Per level number of modules:         [        383,         658,         348,          42,           2,           0] (sum: 1433)
# Per level number of leaf nodes:      [          0,         780,        3133,         927,          90,           5] (sum: 4935)
# Per level average child degree:      [        383,     3.75457,     5.29027,     2.78448,     2.19048,         2.5] (average: 27.2324)
# Per level codelength for modules:    [0.345407785, 1.598078272, 0.069378183, 0.001371896, 0.000124130, 0.000000000] (sum: 2.014360266)
# Per level codelength for leaf nodes: [0.000000000, 0.038504669, 2.932561519, 0.284275282, 0.007249317, 0.000298268] (sum: 3.262889054)
# Per level codelength total:          [0.345407785, 1.636582941, 3.001939702, 0.285647178, 0.007373446, 0.000298268] (sum: 5.277249320)
#
# ===================================================
#   Infomap ends at 2024-11-29 20:37:48
#   (Elapsed time: 0.085124417s)
# ===================================================
# =======================================================
#   Infomap v2.8.0 starts at 2024-11-29 20:38:20
#   -> Input network:
#   -> No file output!
#   -> Configuration: directed
# =======================================================
#   -> Ordinary network input, using the Map Equation for first order network flows
# Calculating global network flow using flow model 'directed'...
#   -> Using unrecorded teleportation to links.
#   -> PageRank calculation done in 200 iterations.
#
#   => Sum node flow: 1, sum link flow: 1
# Build internal network with 5109 nodes and 9366 links...
#   -> One-level codelength: 10.5133959
#
# ================================================
# Trial 1/1 starting at 2024-11-29 20:38:20
# ================================================
# Two-level compression: 46% 0.29% 0.0681510367% 0.00609235076%
# Partitioned to codelength 1.90037312 + 3.74318971 = 5.643562824 in 843 (838 non-trivial) modules.
# Super-level compression: 2.4533378% to codelength 5.505107164 in 375 top modules.
#
# Recursive sub-structure compression: 29.2263504% 1.30349719% 0.0410536009% 0.00113626403% 0% . Found 6 levels with codelength 5.426538351
#
# => Trial 1/1 finished in 0.087207708s with codelength 5.42653835
#
#
# ================================================
# Summary after 1 trial
# ================================================
# Best end modular solution in 6 levels:
# Per level number of modules:         [        375,         652,         378,          63,           4,           0] (sum: 1472)
# Per level number of leaf nodes:      [          0,         768,        3150,        1041,         143,           7] (sum: 5109)
# Per level average child degree:      [        375,     3.78667,     5.41104,     2.92063,     2.33333,        1.75] (average: 25.6301)
# Per level codelength for modules:    [0.308673019, 1.678185788, 0.090660167, 0.003006609, 0.000000000, 0.000000000] (sum: 2.080525583)
# Per level codelength for leaf nodes: [0.000000000, 0.034430564, 2.932526938, 0.364386038, 0.014460973, 0.000208255] (sum: 3.346012768)
# Per level codelength total:          [0.308673019, 1.712616352, 3.023187106, 0.367392647, 0.014460973, 0.000208255] (sum: 5.426538351)
#
# ===================================================
#   Infomap ends at 2024-11-29 20:38:20
#   (Elapsed time: 0.095874417s)
# ===================================================
# =======================================================
#   Infomap v2.8.0 starts at 2024-11-29 20:38:56
#   -> Input network:
#   -> No file output!
#   -> Configuration: directed
# =======================================================
#   -> Ordinary network input, using the Map Equation for first order network flows
# Calculating global network flow using flow model 'directed'...
#   -> Using unrecorded teleportation to links.
#   -> PageRank calculation done in 200 iterations.
#
#   => Sum node flow: 1, sum link flow: 1
# Build internal network with 5288 nodes and 9946 links...
#   -> One-level codelength: 10.5634556
#
# ================================================
# Trial 1/1 starting at 2024-11-29 20:38:56
# ================================================
# Two-level compression: 45% 0.46% 0.0577069812% 0.0310836213% 0.0047560258%
# Partitioned to codelength 2.0005394 + 3.79152318 = 5.792062583 in 856 (854 non-trivial) modules.
# Super-level compression: 2.91520015% to codelength 5.623212366 in 376 top modules.
#
# Recursive sub-structure compression: 26.9634975% 0.493318266% 0.0329323048% 0.000532913064% 0% . Found 6 levels with codelength 5.544980409
#
# => Trial 1/1 finished in 0.089455125s with codelength 5.54498041
#
#
# ================================================
# Summary after 1 trial
# ================================================
# Best end modular solution in 6 levels:
# Per level number of modules:         [        376,         718,         354,          56,           2,           0] (sum: 1506)
# Per level number of leaf nodes:      [          0,         759,        3499,         892,         128,          10] (sum: 5288)
# Per level average child degree:      [        376,     3.92819,      5.3663,     2.67797,     2.32143,           5] (average: 25.1317)
# Per level codelength for modules:    [0.413647311, 1.683331027, 0.057724015, 0.001822134, 0.000193264, 0.000000000] (sum: 2.156717751)
# Per level codelength for leaf nodes: [0.000000000, 0.028304571, 3.097450862, 0.251658812, 0.009205515, 0.001642900] (sum: 3.388262659)
# Per level codelength total:          [0.413647311, 1.711635598, 3.155174877, 0.253480945, 0.009398779, 0.001642900] (sum: 5.544980409)
#
# ===================================================
#   Infomap ends at 2024-11-29 20:38:56
#   (Elapsed time: 0.098353041s)
# ===================================================
# =======================================================
#   Infomap v2.8.0 starts at 2024-11-29 20:39:33
#   -> Input network:
#   -> No file output!
#   -> Configuration: directed
# =======================================================
#   -> Ordinary network input, using the Map Equation for first order network flows
# Calculating global network flow using flow model 'directed'...
#   -> Using unrecorded teleportation to links.
#   -> PageRank calculation done in 200 iterations.
#
#   => Sum node flow: 1, sum link flow: 1
# Build internal network with 5473 nodes and 10462 links...
#   -> One-level codelength: 10.6220262
#
# ================================================
# Trial 1/1 starting at 2024-11-29 20:39:33
# ================================================
# Two-level compression: 44% 0.62% 0.0792620475% 0.0106093787%
# Partitioned to codelength 2.0393393 + 3.89697848 = 5.936317781 in 872 (871 non-trivial) modules.
# Super-level compression: 2.81404895% to codelength 5.769266893 in 369 top modules.
#
# Recursive sub-structure compression: 27.4270284% 0.472841947% 0.0337699615% 0.00049405974% 0% . Found 6 levels with codelength 5.698990492
#
# => Trial 1/1 finished in 0.088347834s with codelength 5.69899049
#
#
# ================================================
# Summary after 1 trial
# ================================================
# Best end modular solution in 6 levels:
# Per level number of modules:         [        369,         741,         360,          59,           2,           0] (sum: 1531)
# Per level number of leaf nodes:      [          0,         753,        3667,         903,         140,          10] (sum: 5473)
# Per level average child degree:      [        369,     4.04878,     5.43455,     2.67222,     2.40678,           5] (average: 23.8517)
# Per level codelength for modules:    [0.376268390, 1.795899272, 0.057869385, 0.002074836, 0.000184150, 0.000000000] (sum: 2.232296033)
# Per level codelength for leaf nodes: [0.000000000, 0.025701785, 3.162026394, 0.266409743, 0.010991113, 0.001565424] (sum: 3.466694458)
# Per level codelength total:          [0.376268390, 1.821601057, 3.219895779, 0.268484579, 0.011175263, 0.001565424] (sum: 5.698990492)
#
# ===================================================
#   Infomap ends at 2024-11-29 20:39:33
#   (Elapsed time: 0.097947792s)
# ===================================================
#    Year  Community ID  Size  Number of Women  Percentage of Women  \
# 0  2002             1     2                0                  0.0
# 1  2002             2     2                0                  0.0
# 2  2002             3     2                0                  0.0
# 3  2003             1     4                2                 50.0
# 4  2003             2     2                0                  0.0
#
#                                              Members
# 0                       Joseph Lister, Louis Pasteur
# 1                      Erwin Schrödinger, Paul Dirac
# 2                   Linus Torvalds, Richard Stallman
# 3  Marie Curie, Pierre Curie, Irène Joliot-Curie,...
# 4                  Ernst Mayr, Theodosius Dobzhansky
#    Year  Community ID  Size  Number of Women  Percentage of Women  \
# 0  2005             1   163                8             4.907975
# 1  2005             2    94                1             1.063830
# 2  2006             1   364               15             4.120879
# 3  2006             2   276                5             1.811594
# 4  2007             1   194                7             3.608247
#
#                                              Members
# 0  Albert Einstein, Bertrand Russell, Henri Poinc...
# 1  Ernst Mayr, Theodosius Dobzhansky, Erwin Stres...
# 2  Albert Einstein, Werner Heisenberg, Arnold Som...
# 3  Isaac Newton, Robert Hooke, Isaac Barrow, John...
# 4  Albert Einstein, Henri Poincaré, Ernst Mach, P...

# %% [markdown]
# #### Output test
# Verifying that the output summary table looks correct

# %%
test= all_communities_df[all_communities_df['Year'] == 2017]

# %%
test
# Out:
#      Year  Community ID  Size  Number of Women  Percentage of Women  \
# 122  2017             1   726               54             7.438017
# 123  2017             2   508               24             4.724409
# 124  2017             3   811               39             4.808878
# 125  2017             4   578               32             5.536332
# 126  2017             5   494               50            10.121457
# 127  2017             6   175                8             4.571429
# 128  2017             7   150               10             6.666667
# 129  2017             8    76                6             7.894737
# 130  2017             9   100                6             6.000000
# 131  2017            10   148                5             3.378378
# 132  2017            11   110               11            10.000000
# 133  2017            12    94               17            18.085106
# 134  2017            15    53                5             9.433962
#
#                                                Members
# 122  Bertrand Russell, Ludwig Wittgenstein, Kurt Gö...
# 123  Albert Einstein, Paul Dirac, Erwin Schrödinger...
# 124  Georges Cuvier, Étienne Geoffroy Saint-Hilaire...
# 125  Jean-Baptiste Biot, François Arago, Claude-Lou...
# 126  Gaston Julia, Louis de Broglie, Émile Picard, ...
# 127  Johann Friedrich Gmelin, Peter Simon Pallas, L...
# 128  Paul Erdős, Fan Chung, Ronald Graham, Béla Bol...
# 129  Jean-Marie Pelt, Trinh Xuan Thuan, Théodore Mo...
# 130  Thomas Edison, Nikola Tesla, Joseph Swan, Henr...
# 131  Joseph Banks, Carl Peter Thunberg, Johann Rein...
# 132  Manuel Blum, Umesh Vazirani, Vijay Vazirani, M...
# 133  Terence Tao, Enrico Bombieri, Emmanuel Candès,...
# 134  Jean Jouzel, Claude Lorius, Susan Solomon, Pau...
